# %% [markdown]
# ## Module Imports

# %%
from treetime.utils import parse_dates
from treetime import TreeTime
from Bio import Phylo
import random

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib import cm

from datetime import datetime
import pandas as pd

# %% [markdown]
# ## Setup input file paths

# %%
meta_path = "../Assembly_Modern/nextstrain/metadata_nextstrain_geocode_state.tsv"
tree_path = "../Assembly_Modern/iqtree/iqtree.core-filter0_bootstrap.treefile"
aln_path = "../Assembly_Modern/snippy_multi/snippy-core.full_CHROM.filter0.fasta"

# %% [markdown]
# ## Constants and Variables

# %%
NUM_SAMPLE_REMOVE = 20
NUM_ITER = 1
NO_DATA_CHAR = "?"
VAL_DATE_REMOVE = [1894.00, 2019.00]

random.seed(1753143)

# %% [markdown]
# ## Parse the dates

# %%
dates = parse_dates(date_file=meta_path, date_col="BioSampleCollectionDate")
# Out:
# Attempting to parse dates...
# 	Using column 'strain' as name. This needs match the taxon names in the tree!!
# 	Using column 'BioSampleCollectionDate' as date.

# %% [markdown]
# ## Parse the tree

# %%
tree = Phylo.read(tree_path, "newick")
tree_tip_names = [t.name for t in tree.get_terminals()]

# %% [markdown]
# ## Tip-Dating: Randomly select the tip samples

# %%
dict_sample_remove = {}

for i in range(0,NUM_SAMPLE_REMOVE):
    
    # Retrieve tip name and val (date)
    tip = random.choice(list(dates.keys()))
    tip_val = dates[tip]
    
    # Check that it is a float (and not a list range)
    # And that it is actually in the input tree
    while type(tip_val) != type(0.1) or tip not in tree_tip_names:
        tip = random.choice(list(dates.keys()))
        tip_val = dates[tip] 
        
    dict_sample_remove[tip] = tip_val
    
    # Remove the metadata from the dates object
    dates[tip] = VAL_DATE_REMOVE

# %% [markdown]
# ## Node-Dating: identify the internal nodes

# %%
## Black Death Node

## Root Node

# %% [markdown]
# ## Treetime relaxed clock analysis

# %%
tt_relaxed = TreeTime(tree = tree_path,
                      aln = aln_path,
                      verbose = 4,
                      dates = dates)
# Out:
# 0.00	-TreeAnc: set-up
#
# 60.11	-SequenceData: loaded alignment.
#
# 60.12	-SeqData: making compressed alignment...
#
# 163.41	-SequenceData: constructed compressed alignment...
# 182.48	--ClockTree: Setting precision to level 2
#
# 182.51	-ClockTree._assign_dates: assigned date contraints to 476 out of 476
#       	 tips.

# %%
tt_relaxed.run(#branch_length_mode = "input", # Don't optimize branch lengths
               branch_length_mode = "joint",
               n_iqd=3,
               root=None,
               infer_gtr=True,
               resolve_polytomies=False,
               relaxed_clock={"slack":5.0, "coupling":1.0},
               max_iter=3,
               Tc="skyline",
               use_covariation=False, # covariation is only for strict molecular clock
               time_marginal=True, # Enable final round for error bar estimation,
               verbose=4,
              )
# Out:
# 182.51	-TreeAnc.optimize_tree: sequences...
#
# 182.51	-TreeAnc.infer_ancestral_sequences with method: probabilistic, joint
#
# 182.51	WARNING: Previous versions of TreeTime (<0.7.0) RECONSTRUCTED sequences
#       	of tips at positions with AMBIGUOUS bases. This resulted in unexpected
#       	behavior is some cases and is no longer done by default. If you want to
#       	replace those ambiguous sites with their most likely state, rerun with
#       	`reconstruct_tip_states=True` or `--reconstruct-tip-states`.
# 182.51	--TreeAnc._ml_anc_joint: type of reconstruction: Joint
# 182.51	---TreeAnc._ml_anc_joint: Walking up the tree, computing likelihoods...
# 183.79	---TreeAnc._ml_anc_joint: Walking down the tree, computing maximum
#       	   likelihood sequences...
# 183.84	---TreeAnc._ml_anc_joint: ...done
# 183.84	--TreeAnc.infer_gtr: counting mutations...
# 190.31	---TreeAnc.infer_gtr: counting mutations...done
#
# 190.31	-GTR: with alphabet: ['A', 'C', 'G', 'T', '-']
# 190.31	--GTR: ambiguous character: N
# 190.31	---GTR: init with dummy values!
#
# 190.32	-GTR: model inference
# 190.32	---GTR inference iteration 0 change: 0.447213595499958
# 190.32	---GTR inference iteration 1 change: 0.22412880102466728
# 190.32	---GTR inference iteration 2 change: 1.6417785482721464e-05
# 190.32	--The model allows for gaps which are estimated to occur at a low
#       	  fraction of 4.367e-06 this can potentially result in artificats. gap
#       	  fraction will be set to 0.0100
# 190.32	--TreeAnc.infer_gtr: setting overall rate to 1.0...
# 190.32	--TreeAnc._ml_anc_joint: type of reconstruction: Joint
# 190.32	---TreeAnc._ml_anc_joint: Walking up the tree, computing likelihoods...
# 191.49	---TreeAnc._ml_anc_joint: Walking down the tree, computing maximum
#       	   likelihood sequences...
# 191.54	---TreeAnc._ml_anc_joint: ...done
#
# 191.55	-TreeAnc.optimize_branch_length: running branch length optimization using
#       	 jointML ancestral sequences
#
# 192.84	-TreeAnc.prune_short_branches: pruning short branches (max prob at
#       	 zero)...
#
# 192.98	-TreeAnc.infer_ancestral_sequences with method: probabilistic, joint
# 192.98	--TreeAnc._ml_anc_joint: type of reconstruction: Joint
# 192.98	---TreeAnc._ml_anc_joint: Walking up the tree, computing likelihoods...
# 193.97	---TreeAnc._ml_anc_joint: Walking down the tree, computing maximum
#       	   likelihood sequences...
# 193.98	---TreeAnc._ml_anc_joint: ...done
# 193.99	--TreeAnc.optimize_tree: Iteration 1. #Nuc changed since prev
#       	  reconstructions: 0
# 193.99	--TreeAnc.optimize_tree: Unconstrained sequence LH:-1302309.609797
# 194.20	--ClockTree.date2dist: Setting new molecular clock. rate=-9.032e-08,
#       	  R^2=0.0079
# 194.21	---TreeTime.ClockFilter: marking GCA_000186725.1_ASM18672v1_genomic as
#       	   outlier, residual 3.012606 interquartile distances
# 194.21	---TreeTime.ClockFilter: marking GCA_008630375.1_ASM863037v1_genomic as
#       	   outlier, residual 4.257954 interquartile distances
# 194.21	---TreeTime.ClockFilter: marking GCA_003086115.1_ASM308611v1_genomic as
#       	   outlier, residual 3.992870 interquartile distances
# 194.21	---TreeTime.ClockFilter: marking GCA_003086075.1_ASM308607v1_genomic as
#       	   outlier, residual 3.507885 interquartile distances
# 194.21	---TreeTime.ClockFilter: marking GCA_001613865.1_ASM161386v1_genomic as
#       	   outlier, residual 4.189250 interquartile distances
# 194.21	---TreeTime.ClockFilter: marking
#       	   GCA_000987005.2_YPES002-SEQ-1-ASM-1_genomic as outlier, residual
#       	   8.634927 interquartile distances
# 194.21	---TreeTime.ClockFilter: marking
#       	   GCA_000987005.1_YPES002-SEQ-1-ASM-1_genomic as outlier, residual
#       	   8.634927 interquartile distances
# 194.21	---TreeTime.ClockFilter: marking
#       	   GCA_000987005.3_YPES002-SEQ-1-ASM-1_genomic as outlier, residual
#       	   8.634927 interquartile distances
# 194.21	---TreeTime.ClockFilter: marking GCA_000168835.1_ASM16883v1_genomic as
#       	   outlier, residual 12.621200 interquartile distances
#
# 194.24	-TreeAnc.optimize_tree: sequences...
#
# 194.24	-TreeAnc.infer_ancestral_sequences with method: probabilistic, joint
# 194.24	--TreeAnc._ml_anc_joint: type of reconstruction: Joint
# 194.24	---TreeAnc._ml_anc_joint: Walking up the tree, computing likelihoods...
# 195.18	---TreeAnc._ml_anc_joint: Walking down the tree, computing maximum
#       	   likelihood sequences...
# 195.19	---TreeAnc._ml_anc_joint: ...done
#
# 195.20	-TreeAnc.optimize_branch_length: running branch length optimization using
#       	 jointML ancestral sequences
#
# 196.13	-TreeAnc.infer_ancestral_sequences with method: probabilistic, joint
# 196.13	--TreeAnc._ml_anc_joint: type of reconstruction: Joint
# 196.13	---TreeAnc._ml_anc_joint: Walking up the tree, computing likelihoods...
# 197.07	---TreeAnc._ml_anc_joint: Walking down the tree, computing maximum
#       	   likelihood sequences...
# 197.08	---TreeAnc._ml_anc_joint: ...done
# 197.09	--TreeAnc.optimize_tree: Iteration 1. #Nuc changed since prev
#       	  reconstructions: 0
# 197.09	--TreeAnc.optimize_tree: Unconstrained sequence LH:-1302309.609797
#
# 197.09	###TreeTime.run: INITIAL ROUND
#
# 197.09	-ClockTree: Maximum likelihood tree optimization with temporal
#       	 constraints
# 197.09	--ClockTree.init_date_constraints...
# 197.09	---ClockTree.init_date_constraints: Initializing branch length
#       	   interpolation objects...
# 202.70	--ClockTree.date2dist: Setting new molecular clock. rate=3.095e-08,
#       	  R^2=0.0020
# 202.71	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 202.71	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 202.71	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 202.71	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 202.71	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 202.71	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 202.71	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 202.71	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 202.72	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 202.72	--ClockTree - Joint reconstruction:  Propagating leaves -> root...
# 211.34	--ClockTree - Joint reconstruction:  Propagating root -> leaves...
# 211.37	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 211.37	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 211.37	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 211.37	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 211.37	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 211.38	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 211.38	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 211.38	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 211.38	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 211.38	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
#
# 211.38	###TreeTime.run: ITERATION 1 out of 3 iterations
#
# 211.38	-TreeTime.run: adding coalescent prior with Tc=const
# 213.40	--optimized Tc to 0.000413
# relaxed_clock {'slack': 5.0, 'coupling': 1.0}
# 213.58	--TreeTime.relaxed_clock: slack=5.000000, coupling=1.000000
#
# 213.59	-ClockTree: Maximum likelihood tree optimization with temporal
#       	 constraints
# 213.59	--ClockTree.init_date_constraints...
# 213.59	---ClockTree.init_date_constraints: Initializing branch length
#       	   interpolation objects...
# 219.13	--ClockTree.date2dist: Setting new molecular clock. rate=3.095e-08,
#       	  R^2=0.0020
# 219.13	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 219.14	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 219.14	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 219.14	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 219.14	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 219.14	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 219.14	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 219.14	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 219.14	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 219.14	--ClockTree - Joint reconstruction:  Propagating leaves -> root...
# 233.72	--ClockTree - Joint reconstruction:  Propagating root -> leaves...
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 233.80	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
#
# 233.80	-TreeAnc.infer_ancestral_sequences with method: ml, joint
# 233.80	--TreeAnc._ml_anc_joint: type of reconstruction: Joint
# 233.80	---TreeAnc._ml_anc_joint: Walking up the tree, computing likelihoods...
# 234.81	---TreeAnc._ml_anc_joint: Walking down the tree, computing maximum
#       	   likelihood sequences...
# 234.83	---TreeAnc._ml_anc_joint: ...done
#
# 234.88	###TreeTime.run: ITERATION 2 out of 3 iterations
#
# 234.88	-TreeTime.run: adding coalescent prior with Tc=const
# 236.59	--optimized Tc to 0.000346
# relaxed_clock {'slack': 5.0, 'coupling': 1.0}
# 236.76	--TreeTime.relaxed_clock: slack=5.000000, coupling=1.000000
#
# 236.77	-ClockTree: Maximum likelihood tree optimization with temporal
#       	 constraints
# 236.77	--ClockTree.init_date_constraints...
# 236.77	---ClockTree.init_date_constraints: Initializing branch length
#       	   interpolation objects...
# 242.66	--ClockTree.date2dist: Setting new molecular clock. rate=3.095e-08,
#       	  R^2=0.0020
# 242.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 242.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 242.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 242.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 242.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 242.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 242.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 242.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 242.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 242.68	--ClockTree - Joint reconstruction:  Propagating leaves -> root...
# 257.36	--ClockTree - Joint reconstruction:  Propagating root -> leaves...
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 257.45	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
#
# 257.45	-TreeAnc.infer_ancestral_sequences with method: ml, joint
# 257.45	--TreeAnc._ml_anc_joint: type of reconstruction: Joint
# 257.45	---TreeAnc._ml_anc_joint: Walking up the tree, computing likelihoods...
# 258.42	---TreeAnc._ml_anc_joint: Walking down the tree, computing maximum
#       	   likelihood sequences...
# 258.44	---TreeAnc._ml_anc_joint: ...done
#
# 258.50	###TreeTime.run: ITERATION 3 out of 3 iterations
#
# 258.50	-TreeTime.run: adding coalescent prior with Tc=skyline
# 258.56	--Coalescent:optimize_skyline:... current LH: 5032.609848
# 285.71	--Coalescent:optimize_skyline:...done. new LH: 5212.658679
# 285.71	--optimized a skyline
# relaxed_clock {'slack': 5.0, 'coupling': 1.0}
# 285.88	--TreeTime.relaxed_clock: slack=5.000000, coupling=1.000000
#
# 285.89	-ClockTree: Maximum likelihood tree optimization with temporal
#       	 constraints
# 285.89	--ClockTree.init_date_constraints...
# 285.89	---ClockTree.init_date_constraints: Initializing branch length
#       	   interpolation objects...
# 291.66	--ClockTree.date2dist: Setting new molecular clock. rate=3.095e-08,
#       	  R^2=0.0020
# 291.66	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 291.66	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 291.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 291.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 291.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 291.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 291.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 291.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 291.67	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 291.67	--ClockTree - Joint reconstruction:  Propagating leaves -> root...
# 307.00	--ClockTree - Joint reconstruction:  Propagating root -> leaves...
# 307.09	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 307.09	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 307.09	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 307.09	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 307.09	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 307.10	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 307.10	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 307.10	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 307.10	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 307.10	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
#
# 307.10	-TreeAnc.infer_ancestral_sequences with method: ml, joint
# 307.10	--TreeAnc._ml_anc_joint: type of reconstruction: Joint
# 307.10	---TreeAnc._ml_anc_joint: Walking up the tree, computing likelihoods...
# 308.08	---TreeAnc._ml_anc_joint: Walking down the tree, computing maximum
#       	   likelihood sequences...
# 308.09	---TreeAnc._ml_anc_joint: ...done
#
# 308.15	###TreeTime.run: FINAL ROUND - confidence estimation via marginal
#       	reconstruction
#
# 308.15	-ClockTree: Maximum likelihood tree optimization with temporal
#       	 constraints
# 308.15	--ClockTree.init_date_constraints...
# 308.15	---ClockTree.init_date_constraints: Initializing branch length
#       	   interpolation objects...
# 313.97	--ClockTree.date2dist: Setting new molecular clock. rate=3.095e-08,
#       	  R^2=0.0020
# 313.98	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 313.98	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 313.98	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 313.98	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 313.98	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 313.98	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 313.98	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 313.98	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 313.98	----ClockTree.init_date_constraints -- WARNING: Branch is marked as bad,
#       	    excluding it from the optimization process. Date constraint will be
#       	    ignored!
# 313.98	--ClockTree - Marginal reconstruction:  Propagating leaves -> root...
# 336.85	--ClockTree - Marginal reconstruction:  Propagating root -> leaves...
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
# 373.11	----ClockTree.convert_dates -- WARNING: node which is marked as "BAD"
#       	    optimized later than present day
#
# 373.11	TreeTime: the following tips have been marked as outliers. Their date
#       	constraints were not used. Please remove them from the tree. Their dates
#       	have been reset:
#
# 373.11	GCA_000186725.1_ASM18672v1_genomic, input date: 1940.0, apparent date:
#       	2289.12
#
# 373.11	GCA_000186725.1_ASM18672v1_genomic has been pruned from the tree.
#
# 373.11	GCA_008630375.1_ASM863037v1_genomic, input date: 1982.0, apparent date:
#       	2967.99
#
# 373.11	GCA_008630375.1_ASM863037v1_genomic has been pruned from the tree.
#
# 373.11	GCA_003086115.1_ASM308611v1_genomic, input date: 1988.0, apparent date:
#       	2942.48
#
# 373.11	GCA_003086115.1_ASM308611v1_genomic has been pruned from the tree.
#
# 373.11	GCA_003086075.1_ASM308607v1_genomic, input date: 1983.0, apparent date:
#       	2778.73
#
# 373.11	GCA_003086075.1_ASM308607v1_genomic has been pruned from the tree.
#
# 373.11	GCA_001613865.1_ASM161386v1_genomic, input date: 1971.0, apparent date:
#       	3364.62
#
# 373.12	GCA_001613865.1_ASM161386v1_genomic has been pruned from the tree.
#
# 373.12	GCA_000987005.2_YPES002-SEQ-1-ASM-1_genomic, input date: [1920.0,
#       	1943.99], apparent date: 5564.78
#
# 373.12	GCA_000987005.2_YPES002-SEQ-1-ASM-1_genomic has been pruned from the
#       	tree.
#
# 373.12	GCA_000987005.1_YPES002-SEQ-1-ASM-1_genomic, input date: [1920.0,
#       	1943.99], apparent date: 5564.78
#
# 373.12	GCA_000987005.1_YPES002-SEQ-1-ASM-1_genomic has been pruned from the
#       	tree.
#
# 373.12	GCA_000987005.3_YPES002-SEQ-1-ASM-1_genomic, input date: [1920.0,
#       	1943.99], apparent date: 5564.78
#
# 373.12	GCA_000987005.3_YPES002-SEQ-1-ASM-1_genomic has been pruned from the
#       	tree.
#
# 373.12	GCA_000168835.1_ASM16883v1_genomic, input date: 2001.0, apparent date:
#       	7474.93
#
# 373.12	GCA_000168835.1_ASM16883v1_genomic has been pruned from the tree.
# 'success'

# %% [markdown]
# ## Compare actual with estimated

# %%
dict_sample_estimate = {}
list_ci_contain_sample_date = []

# Get the terminal nodes from the estimated relaxed clock model
for t in tt_relaxed.tree.get_terminals():
    if t.name in dict_sample_remove:
        conf = tt_relaxed.get_max_posterior_region(t, fraction=0.9)
        lower_conf = conf[0]
        upper_conf = conf[1]
        sample_date = dict_sample_remove[t.name]
        dict_sample_estimate[t.name] = {'sample_date': sample_date,
                                        'estimate_date': t.numdate,
                                        'lower_conf': lower_conf,
                                        'upper_conf': upper_conf
                                       }
        
        if lower_conf <= sample_date and upper_conf >= sample_date:
            list_ci_contain_sample_date.append(t.name)
        
perc_ci_contain_sample_date = (len(list_ci_contain_sample_date) / len(dict_sample_estimate)) * 100
  

#for sample in dict_sample_estimate:
#    print(sample)
#    print("\t", dict_sample_estimate[sample]['sample_date'])
#    print("\t", dict_sample_estimate[sample]['estimate_date'])
#    print("\t", dict_sample_estimate[sample]['lower_conf'])
#    print("\t", dict_sample_estimate[sample]['upper_conf'])

# %% [markdown]
# ## Visualize differences

# %% [markdown]
# ### Plot data

# %%
# Scatter plot of actual sampling dates

list_sample_name = list(dict_sample_estimate.keys())
list_sample_date = [dict_sample_estimate[sample]['sample_date'] for sample in dict_sample_estimate]
list_estimate_date = [dict_sample_estimate[sample]['estimate_date'] for sample in dict_sample_estimate]
list_lower_conf = [dict_sample_estimate[sample]['lower_conf'] for sample in dict_sample_estimate]
list_upper_conf = [dict_sample_estimate[sample]['upper_conf'] for sample in dict_sample_estimate]

# Lists for error bar calculations
list_lower_diff = []
list_upper_diff = []

zip_estimate_lower = zip(list_estimate_date, list_lower_conf)
for list1_i, list2_i in zip_estimate_lower:
    list_lower_diff.append(list1_i-list2_i)
    
zip_estimate_upper = zip(list_upper_conf, list_estimate_date)
for list1_i, list2_i in zip_estimate_upper:
    list_upper_diff.append(list1_i-list2_i)

# %% [markdown]
# ### Plotting

# %%
plt.figure(dpi=400)
ax = plt.subplot()
#print(fig)

# 90% Confidence Interval
plt.errorbar(
    x=list_sample_name,
    y=list_estimate_date,
    yerr=[list_lower_diff, list_upper_diff],
    linestyle='',
    c="#e41a1c",
    label="90% Confidence Interval (Marginal)",
)

# Sampling date scatter plot
scatter_sample = plt.scatter(x=list_sample_name, y=list_sample_date, c="#377eb8", label = "Sampling Date")

# Estimated date scatter plot
plt.scatter(x=list_sample_name, y=list_estimate_date, c="#e41a1c", label = "Estimated Date (Joint)", )

perc_string = "{0:.0f}% of confidence intervals \ncontain sampling date".format(perc_ci_contain_sample_date)
                                                                                
# Add text
plt.text(1.05, 0.5, 
         perc_string, 
         horizontalalignment='left', 
         verticalalignment='center', 
         transform=ax.transAxes)

# Formatting
plt.xticks(rotation=90)
plt.grid(True)

# Place a legend to the right of this smaller subplot.
legend1 = plt.legend(handles=scatter_sample.legend_elements()[0],
                     labels= [""],
                     bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)


#plt.gca().add_artist(legend1)

# Title
plt.title("Strong Prior Relaxed Clock\n(slack=5.0; coupling=1.0)")
plt.savefig('strongprior-relaxed-clock_leave-one-out.png', dpi=400, bbox_inches = "tight")
# Out:
# /home/ktmeaton/miniconda3/envs/nextstrain-8.0.0/lib/python3.6/site-packages/matplotlib/collections.py:988: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "

# %% [markdown]
# ## Plot Trees

# %%
vmin, vmax = 0.5, 1.5 # color branches according to the rate deviation

for n in tt_relaxed.tree.find_clades():
    if n.up:
        n.color = [int(x*255) for x in cm.cool((min(max(vmin, n.branch_length_interpolator.gamma),vmax)-vmin)/(vmax-vmin))[:3]]
    else:
        n.color = [200,200,200]

# %%
# draw trees inferred with the relaxed model
plt.figure(dpi=400)
fig = plt.figure()
ax = plt.subplot()

# Remove the outgroup
nodes_find_root = ["GCA_000323845.1_ASM32384v1_genomic","GCA_000323485.1_ASM32348v1_genomic","GCA_001972405.1_ASM197240v1_genomic"]

subtree = tt_relaxed.tree.common_ancestor(nodes_find_root)
for c in subtree.clades:
    if not c.is_terminal():
        subtree = c
        break

# Draw tree 
subtree.ladderize(reverse=True) # Flip upside down
Phylo.draw(subtree, axes=ax, 
           show_confidence=False, 
           label_func = lambda x:'', 
           do_show=False)

ax.set_title("Strong Prior Relaxed Clock\n(slack=5.0; coupling=1.0)")
plt.savefig('strongprior-relaxed-clock_rate-variation.png', dpi=400, bbox_inches = "tight")

# %% [markdown]
# ## Skyline

# %%
skyline, conf = tt_relaxed.merger_model.skyline_inferred(gen=50, confidence=2)

plt.figure(dpi=400)
fig = plt.figure()
ax = plt.subplot()

plt.fill_between(skyline.x, conf[0], conf[1], color=(0.8, 0.8, 0.8))
plt.plot(skyline.x, skyline.y, label='maximum likelihood skyline')
plt.yscale('log')
plt.legend()
plt.ticklabel_format(axis='x',useOffset=False)

ax.set_title("Strong Prior Relaxed Clock\n(slack=5.0; coupling=1.0)")

plt.savefig('strong-prior-relaxed-clock_skyline.png', dpi=400)
