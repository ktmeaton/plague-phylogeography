# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Paths

# %%
results_dir = "/mnt/c/Users/ktmea/Projects/plague-phylogeography-projects/main/"
iqtree_dir    = os.path.join(results_dir, "iqtree/all/chromosome/full/filter5/")


metadata_path = os.path.join(iqtree_dir + "filter-taxa/metadata.tsv")
print(metadata_path)
# Out:
# /mnt/c/Users/ktmea/Projects/plague-phylogeography-projects/main/iqtree/all/chromosome/full/filter5/filter-taxa/metadata.tsv

# %% [markdown]
# ## Variables

# %%
NO_DATA_CHAR = "NA"

# ------------------------------------------
# Plotting
plt.rcParams['axes.facecolor']    ='white'
plt.rcParams['savefig.facecolor'] ='white'
plt.rcParams['savefig.dpi']       = 400
plt.rcParams['svg.fonttype']      = 'none'

# %% [markdown]
# ---
# # Import

# %%
metadata_df = pd.read_csv(metadata_path, sep='\t', index_col = 0)
metadata_df.fillna(NO_DATA_CHAR, inplace=True)

display(metadata_df)
# Out:
#                                       strain         date      date_bp  \
# sample
# Reference                               CO92         1992          -29
# GCA_009909635.1_ASM990963v1_genomic     9_10       1923.0          -98
# GCA_009669545.1_ASM966954v1_genomic    42126       2006.0          -15
# GCA_009669555.1_ASM966955v1_genomic    42123       2005.0          -16
# GCA_009669565.1_ASM966956v1_genomic    42118       2005.0          -16
# ...                                      ...          ...          ...
# SAMEA7313243_45                       Azov38  [1400:1700]  [-621:-321]
# SAMEA7313246_49                      Gdansk8  [1400:1700]  [-621:-321]
# SAMEA6651390                          AGU010  [1435:1477]  [-586:-544]
# SAMEA6637004                          AGU025  [1441:1612]  [-580:-409]
# SAMEA6637002                         AGU007B  [1463:1632]  [-558:-389]
#
#                                                       country  \
# sample
# ...

# %%
## Convert Dataframe to Geopandas

# %%
fig, ax = plt.subplots(1)

sns.scatterplot(ax=ax, data=metadata_df, x="root_rtt_dist", y="root_rtt_dist")
# Out:
# <AxesSubplot:xlabel='root_rtt_dist', ylabel='root_rtt_dist'>
