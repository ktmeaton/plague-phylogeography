# %% [markdown]
# ---
# # 1. SETUP

# %% [markdown]
# ## Modules

# %%
import os
from Bio import Phylo, AlignIO
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors, gridspec, lines
import scipy
import math
import numpy as np
import geopandas
import datetime
import shapely
import copy
from geopy import distance
import geopy
import cartopy.crs as ccrs
from augur import utils, export_v2
import subprocess
import itertools

from functions import *

# %% [markdown]
# ## Paths

# %%
try:
    WILDCARDS = snakemake.wildcards
    project_dir = os.getcwd()
except NameError:
    WILDCARDS = ["all", "chromosome", "full", "5"]
    project_dir = os.path.dirname(os.path.dirname(os.getcwd()))
    
results_dir = os.path.join(project_dir, "results/")

READS_ORIGIN = WILDCARDS[0]
LOCUS_NAME = WILDCARDS[1]
PRUNE = WILDCARDS[2]
MISSING_DATA = WILDCARDS[3]

AUSPICE_PREFIX = "plague-phylogeography-projects_main_{}".format(PRUNE)

# %%
# Manual override
results_dir = "/mnt/c/Users/ktmea/Projects/plague-phylogeography-projects/main/"

# %%
iqtree_dir    = os.path.join(results_dir, "iqtree/all/chromosome/{}/filter{}/".format(PRUNE, MISSING_DATA))
lsd_dir       = os.path.join(results_dir, "lsd/all/chromosome/{}/filter{}/".format(PRUNE, MISSING_DATA))
mugration_dir = os.path.join(results_dir, "mugration/all/chromosome/{}/filter{}/".format(PRUNE, MISSING_DATA))
snippy_dir    = os.path.join(results_dir, "snippy_multi/all/chromosome/{}/filter{}/".format(PRUNE, MISSING_DATA))

# ------------------------------------------
# Trees
divtree_path              = iqtree_dir    + "filter-taxa/iqtree.treefile"
timetree_path             = lsd_dir       + "lsd.timetree.nex"

# ------------------------------------------
# Alignment
constant_sites_path   = results_dir + "snippy_multi/all/chromosome/full/snippy-multi.constant_sites.txt"
aln_path              = iqtree_dir + "filter-sites/snippy-multi.snps.aln"

# ------------------------------------------
# Metadata

auspice_config_path          = results_dir + "config/auspice_config.json"
metadata_path                = iqtree_dir.replace("iqtree","iqtree_stats")    + "/metadata.tsv"

    
# ------------------------------------------
# Output
augur_dir   = os.path.join(results_dir, "augur/all/chromosome/{}/filter{}/ml".format(PRUNE, MISSING_DATA))
auspice_dir = os.path.join(results_dir, "auspice/all/chromosome/{}/filter{}/ml".format(PRUNE, MISSING_DATA))

if not os.path.exists(augur_dir):
    print(augur_dir)
    subprocess.run(["mkdir", "-p", augur_dir]) 
    
if not os.path.exists(auspice_dir):
    print(auspice_dir)
    subprocess.run(["mkdir", "-p", auspice_dir])

# %% [markdown]
# ## Variables

# %%
pd.set_option("display.max_rows", 10, "display.max_columns", None)

NO_DATA_CHAR = "NA"
UNKNOWN_CHAR = "?"
JSON_INDENT=2
CURRENT_YEAR = datetime.datetime.utcnow().year
MUG_CONF = 0.95
ALPHA = 0.05

# ------------------------------------------
# Alignment
with open(constant_sites_path) as infile:
    data = infile.read().strip().split(",")
    constant_sites = sum([int(count) for count in data])

aln = AlignIO.read(aln_path, "fasta")
variant_sites = len(aln[0].seq)
SEQ_LEN = constant_sites + variant_sites

# ------------------------------------------
# Geo
CRS = "epsg:3857"
CRS_EPSG = ccrs.epsg('3857')
world_polygons = geopandas.read_file(geopandas.datasets.get_path("naturalearth_lowres"))


MUG_ATTRIBUTE_LIST = [
    "country",
    "province",
    "continent",
    "host_order",
    "population",
]

# ------------------------------------------
# Plotting
plt.rcParams['axes.facecolor']    ='white'
plt.rcParams['savefig.facecolor'] ='white'
plt.rcParams['savefig.dpi']       = 400
plt.rcParams['svg.fonttype']      = 'none'

# %%
mug_dict = {}

for attr in MUG_ATTRIBUTE_LIST:
    mug_dict[attr] = {}
    mug_dict[attr]["tree_path"] = mugration_dir + attr + ".nex".format(MISSING_DATA)
    mug_dict[attr]["conf_path"] = mugration_dir + attr + "_confidence.csv"
    mug_dict[attr]["states_path"] = mugration_dir + attr + "_states.csv"

# %% [markdown]
# ---
#
# # 2. IMPORT

# %% [markdown]
# ## Mugration Confidence Tables

# %%
states_files = [mug_dict[attr]["states_path"] for attr in mug_dict]
conf_files = [mug_dict[attr]["conf_path"] for attr in mug_dict]

# ----------------------------------------
# Convert character states to numbers
for mugstates,mugconf in zip(states_files, conf_files):
    node_i = 0
    conf_basename = os.path.splitext(mugconf)[0]
    conf_outname = conf_basename + "_tidy.csv"
    i = 0
    state_dict = {}
    with open(mugstates, "r") as infile:
        read_line = infile.readline()
        while read_line:
            split_line = read_line.strip().split(",")
            state = split_line[1]
            if state == "nan":
                state = "NA"
            if state == UNKNOWN_CHAR:
                state_dict[-1] = state
            else:
                state_dict[i] = state
                i += 1
            read_line = infile.readline()
    # Swap first to last place
    final_i = len(state_dict) - 1   
    state_dict[final_i] = "?"
    # Remove old first
    state_dict.pop(-1)

    with open(mugconf, "r") as infile:            
        i = 0
        read_line = infile.readline()
        header = read_line.strip().split(", ")
        header[0] = "name"

        data = ""
        for i in range(0, len(header) - 1):
            char = header[i + 1]
            header[i + 1] = state_dict[i]
        header = ",".join(header)
        read_line = infile.readline()            
        while read_line:
            # Rename internal nodes
            split_line = read_line.split(", ")
            node_name = split_line[0]
            if "NODE" in node_name:
                node_name = "NODE{}".format(node_i)
                node_i += 1
            new_line = ",".join([node_name] + split_line[1:])
            data += new_line
            read_line = infile.readline()
    
    with open(conf_outname, "w") as outfile:
        outfile.write(header + "\n")
        outfile.write(data)

# ----------------------------------------
# Import the tidy files as dataframes

for attr in mug_dict:
    conf_path = mug_dict[attr]["conf_path"]
    tidy_path = os.path.splitext(conf_path)[0] + "_tidy.csv"
    df = pd.read_csv(tidy_path, sep=',', index_col = 0)
    mug_dict[attr]["conf_df"] = df

# %% [markdown]
# ## Trees

# %%
tree_paths = [divtree_path, timetree_path] + [mug_dict[attr]["tree_path"] for attr in mug_dict]

for tree_path in tree_paths:
    tree_ext = os.path.splitext(tree_path)[1]
    if tree_ext == ".nwk" or tree_ext == ".newick" or tree_ext == ".treefile":
        tree = Phylo.read(tree_path, "newick")
    elif tree_ext == ".nex" or tree_ext == ".nexus":
        parse_trees = Phylo.parse(tree_path, "nexus")
        for parse_tree in parse_trees:
            clades = [c for c in parse_tree.find_clades()]
            if len(clades) > 1:
                break
        tree = parse_tree
    tree.ladderize(reverse=False)
    
    if tree_path == divtree_path:
        print("divtree:", os.path.basename(tree_path))
        divtree = tree
    elif tree_path == timetree_path:
        print("timetree:", os.path.basename(tree_path))        
        timetree = tree   
        
    # Check against mugration attributes
    for attr in mug_dict:
        if tree_path == mug_dict[attr]["tree_path"]:
            print(attr + ":", os.path.basename(tree_path))
            mug_dict[attr]["tree"] = tree
# Out:
# divtree: iqtree.treefile
# timetree: lsd.timetree.nex
# country: country.nex
# province: province.nex
# continent: continent.nex
# host_order: host_order.nex
# population: population.nex

# %% [markdown]
# ## Genomic Metadata

# %%
metadata_df = pd.read_csv(metadata_path, sep='\t')
metadata_df.set_index(metadata_df.columns[0], inplace=True)
metadata_df.fillna(NO_DATA_CHAR, inplace=True)

# %% [markdown]
# ## Populations

# %%
population_list = []

for t in divtree.get_terminals():
    population = metadata_df["population"][t.name]
    if population not in population_list:
        population_list.append(population)        
        
print(population_list)
# Out:
# ['0.PRE', '0.PE', '0.ANT', '0.ANT4', '3.ANT', '4.ANT', '2.ANT', '2.MED', '1.PRE', '1.ANT', '1.IN', '1.ORI']

# %% [markdown]
# ## Most Recent Sampling Date for BEAST

# %%
out_path = os.path.join(augur_dir, "most_recent_sampling_dates.tsv")
mrsd_dict = {}

with open(out_path, "w") as outfile:
    for population in population_list:
        df = metadata_df[metadata_df["population"] == population]
        max_date = max(df["date_mean"])
        print(population, max_date)
        outfile.write("{}\t{}\n".format(population, max_date))
        mrsd_dict[population] = max_date
# Out:
# 0.PRE -1686.0
# 0.PE 2014.0
# 0.ANT 2019.0
# 0.ANT4 765.0
# 3.ANT 2017.0
# 4.ANT 2015.0
# 2.ANT 2008.0
# 2.MED 2018.0
# 1.PRE 1767.5
# 1.ANT 2004.0
# 1.IN 2008.0
# 1.ORI 2016.0

# %% [markdown]
# ---
# # 3. MERGE METADATA

# %% [markdown]
# ## Trees

# %%
# Check if they're synchronized
node_i = 0

trees = [divtree, timetree] + [mug_dict[attr]["tree"] for attr in mug_dict]
divtree_num_clades = len([c for c in divtree.find_clades()])
divtree_tip_names = [t.name for t in divtree.get_terminals()]

# Check for synchrony
# Note, no checking for internal order yet
for tree in trees:
    clades = [c for c in tree.find_clades()]
    tip_names = [t.name for t in tree.get_terminals()]
    if (tip_names != divtree_tip_names) or (len(clades) != divtree_num_clades):
        print("ERROR. Trees are not synchronized.")               


# Rename internal nodes
for tree in trees:        
    node_i = 0
    for c in tree.find_clades():
        if not c.name or "NODE" in c.name:
            c.name = "NODE{}".format(node_i)
            node_i += 1

# Extract metadata from divtree
for c in divtree.find_clades():
    
    # ---------------
    # Node type
    node_type = "internal"
    if c.is_terminal():
        node_type = "terminal"
    metadata_df.at[c.name, "node_type"] = node_type

    # ---------------
    # Branch Length
    branch_length = c.branch_length
    if not branch_length:
        branch_length = 0
    metadata_df.at[c.name, "branch_length"] = branch_length    

    # ---------------
    # Branch Support
    # Give terminal nodes 0% confidence
    branch_support = c.confidence
    if c.is_terminal():
        branch_support = 0
    # Internal nodes without confidence can be 0
    elif not c.confidence:
        branch_support = 0
    metadata_df.at[c.name, "branch_support"] = branch_support

    # Confidence category
    branch_support_conf_char = ""
    if branch_support >= 95 and not c.is_terminal():
        branch_support_conf_char = "*"
    metadata_df.at[c.name, "branch_support_conf_char"] = branch_support_conf_char
    if branch_support >= 95:
        metadata_df.at[c.name, "branch_support_conf_category"] = "HIGH"
    else:
        metadata_df.at[c.name, "branch_support_conf_category"] = "LOW"

# Extract metadata from timetree
for c in timetree.find_clades():                    
    if c.comment:
        comment_dict = parse_comment(c.comment)
        for param,val in comment_dict.items():
            rename_param = "timetree_" + param
            metadata_df.at[c.name, rename_param] = val

# Extract metadata from timetree
for attr in mug_dict:
    tree = mug_dict[attr]["tree"]
    
    for c in tree.find_clades():
        if c.comment:
            comment_dict = parse_comment(c.comment)
            for param,val in comment_dict.items():
                rename_param = "mugration_" + param
                metadata_df.at[c.name, rename_param] = val 
            
metadata_df.fillna(NO_DATA_CHAR, inplace=True)
display(metadata_df)
# Out:
#                                     strain    date date_bp  \
# sample
# Reference                             CO92    1992     -29
# GCA_009909635.1_ASM990963v1_genomic   9_10  1923.0     -98
# GCA_009669545.1_ASM966954v1_genomic  42126  2006.0     -15
# GCA_009669555.1_ASM966955v1_genomic  42123  2005.0     -16
# GCA_009669565.1_ASM966956v1_genomic  42118  2005.0     -16
# ...                                    ...     ...     ...
# NODE595                                 NA      NA      NA
# NODE596                                 NA      NA      NA
# NODE597                                 NA      NA      NA
# NODE598                                 NA      NA      NA
# NODE599                                 NA      NA      NA
#
#                                                       country       province  \
# sample
# Reference                            United States of America       Colorado
# GCA_009909635.1_ASM990963v1_genomic                    Russia  Rostov Oblast
# GCA_009669545.1_ASM966954v1_genomic                     China       Xinjiang
# GCA_009669555.1_ASM966955v1_genomic                     China       Xinjiang
# GCA_009669565.1_ASM966956v1_genomic                     China       Xinjiang
# ...                                                       ...            ...
# NODE595                                                    NA             NA
# NODE596                                                    NA             NA
# NODE597                                                    NA             NA
# NODE598                                                    NA             NA
# NODE599                                                    NA             NA
#
#                                     country_lat country_lon province_lat  \
# sample
# Reference                               39.7837    -100.446      38.7252
# GCA_009909635.1_ASM990963v1_genomic     64.6863     97.7453      47.6222
# GCA_009669545.1_ASM966954v1_genomic     35.0001         105      42.4805
# GCA_009669555.1_ASM966955v1_genomic     35.0001         105      42.4805
# GCA_009669565.1_ASM966956v1_genomic     35.0001         105      42.4805
# ...                                         ...         ...          ...
# NODE595                                      NA          NA           NA
# NODE596                                      NA          NA           NA
# NODE597                                      NA          NA           NA
# NODE598                                      NA          NA           NA
# NODE599                                      NA          NA           NA
#
#                                     province_lon      biovar branch_major  \
# sample
# Reference                               -105.608  Orientalis        1.ORI
# GCA_009909635.1_ASM990963v1_genomic      40.7958  Medievalis        2.MED
# GCA_009669545.1_ASM966954v1_genomic      85.4633     Antiqua        0.ANT
# GCA_009669555.1_ASM966955v1_genomic      85.4633     Antiqua        0.ANT
# GCA_009669565.1_ASM966956v1_genomic      85.4633     Antiqua        0.ANT
# ...                                          ...         ...          ...
# NODE595                                       NA          NA           NA
# NODE596                                       NA          NA           NA
# NODE597                                       NA          NA           NA
# NODE598                                       NA          NA           NA
# NODE599                                       NA          NA           NA
#
#                                     branch_minor biosample_accession  \
# sample
# Reference                                 1.ORI1        SAMEA1705942
# GCA_009909635.1_ASM990963v1_genomic       2.MED1        SAMN13632815
# GCA_009669545.1_ASM966954v1_genomic       0.ANT1        SAMN07722925
# GCA_009669555.1_ASM966955v1_genomic       0.ANT1        SAMN07722924
# GCA_009669565.1_ASM966956v1_genomic       0.ANT1        SAMN07722923
# ...                                          ...                 ...
# NODE595                                       NA                  NA
# NODE596                                       NA                  NA
# NODE597                                       NA                  NA
# NODE598                                       NA                  NA
# NODE599                                       NA                  NA
#
#                                                    biosample_comment  \
# sample
# Reference                            KEEP: Assembly Modern Reference
# GCA_009909635.1_ASM990963v1_genomic            KEEP: Assembly Modern
# GCA_009669545.1_ASM966954v1_genomic            KEEP: Assembly Modern
# GCA_009669555.1_ASM966955v1_genomic            KEEP: Assembly Modern
# GCA_009669565.1_ASM966956v1_genomic            KEEP: Assembly Modern
# ...                                                              ...
# NODE595                                                           NA
# NODE596                                                           NA
# NODE597                                                           NA
# NODE598                                                           NA
# NODE599                                                           NA
#
#                                     branch_number      continent date_mean  \
# sample
# Reference                                       1  North America      1992
# GCA_009909635.1_ASM990963v1_genomic             2         Europe      1923
# GCA_009669545.1_ASM966954v1_genomic             0           Asia      2006
# GCA_009669555.1_ASM966955v1_genomic             0           Asia      2005
# GCA_009669565.1_ASM966956v1_genomic             0           Asia      2005
# ...                                           ...            ...       ...
# NODE595                                        NA             NA        NA
# NODE596                                        NA             NA        NA
# NODE597                                        NA             NA        NA
# NODE598                                        NA             NA        NA
# NODE599                                        NA             NA        NA
#
#                                     date_bp_mean date_err      lat      lon  \
# sample
# Reference                                     29        0  38.7252 -105.608
# GCA_009909635.1_ASM990963v1_genomic           98        0  47.6222  40.7958
# GCA_009669545.1_ASM966954v1_genomic           15        0  42.4805  85.4633
# GCA_009669555.1_ASM966955v1_genomic           16        0  42.4805  85.4633
# GCA_009669565.1_ASM966956v1_genomic           16        0  42.4805  85.4633
# ...                                          ...      ...      ...      ...
# NODE595                                       NA       NA       NA       NA
# NODE596                                       NA       NA       NA       NA
# NODE597                                       NA       NA       NA       NA
# NODE598                                       NA       NA       NA       NA
# NODE599                                       NA       NA       NA       NA
#
#                                     host_human sequencing_technology  \
# sample
# Reference                                Human                    NA
# GCA_009909635.1_ASM990963v1_genomic      Human            IonTorrent
# GCA_009669545.1_ASM966954v1_genomic  Non-Human   Illumina Hiseq 2000
# GCA_009669555.1_ASM966955v1_genomic  Non-Human   Illumina Hiseq 2000
# GCA_009669565.1_ASM966956v1_genomic  Non-Human   Illumina Hiseq 2000
# ...                                        ...                   ...
# NODE595                                     NA                    NA
# NODE596                                     NA                    NA
# NODE597                                     NA                    NA
# NODE598                                     NA                    NA
# NODE599                                     NA                    NA
#
#                                         assembly_method  \
# sample
# Reference                                            NA
# GCA_009909635.1_ASM990963v1_genomic      Newbler v. 2.6
# GCA_009669545.1_ASM966954v1_genomic  SOAPdenovo v. 2.04
# GCA_009669555.1_ASM966955v1_genomic  SOAPdenovo v. 2.04
# GCA_009669565.1_ASM966956v1_genomic  SOAPdenovo v. 2.04
# ...                                                 ...
# NODE595                                              NA
# NODE596                                              NA
# NODE597                                              NA
# NODE598                                              NA
# NODE599                                              NA
#
#                                                    host_raw    host_order  \
# sample
# Reference                                             Human         Human
# GCA_009909635.1_ASM990963v1_genomic            Homo sapiens         Human
# GCA_009669545.1_ASM966954v1_genomic      Citellus undulatus      Rodentia
# GCA_009669555.1_ASM966955v1_genomic  Frontopsylla elatoides  Siphonaptera
# GCA_009669565.1_ASM966956v1_genomic      Citellus undulatus      Rodentia
# ...                                                     ...           ...
# NODE595                                                  NA            NA
# NODE596                                                  NA            NA
# NODE597                                                  NA            NA
# NODE598                                                  NA            NA
# NODE599                                                  NA            NA
#
#                                     population_color population  \
# sample
# Reference                                    #ff0000      1.ORI
# GCA_009909635.1_ASM990963v1_genomic          #c5e88a      2.MED
# GCA_009669545.1_ASM966954v1_genomic          #238af5      0.ANT
# GCA_009669555.1_ASM966955v1_genomic          #238af5      0.ANT
# GCA_009669565.1_ASM966956v1_genomic          #238af5      0.ANT
# ...                                              ...        ...
# NODE595                                           NA         NA
# NODE596                                           NA         NA
# NODE597                                           NA         NA
# NODE598                                           NA         NA
# NODE599                                           NA         NA
#
#                                                                  geometry  \
# sample
# Reference                                  POINT (-105.607716 38.7251776)
# GCA_009909635.1_ASM990963v1_genomic         POINT (40.7957942 47.6222451)
# GCA_009669545.1_ASM966954v1_genomic  POINT (85.46334640000001 42.4804953)
# GCA_009669555.1_ASM966955v1_genomic  POINT (85.46334640000001 42.4804953)
# GCA_009669565.1_ASM966956v1_genomic  POINT (85.46334640000001 42.4804953)
# ...                                                                   ...
# NODE595                                                                NA
# NODE596                                                                NA
# NODE597                                                                NA
# NODE598                                                                NA
# NODE599                                                                NA
#
#                                     root_rtt_dist clade_rtt_dist  \
# sample
# Reference                             7.31686e-05             NA
# GCA_009909635.1_ASM990963v1_genomic   7.30501e-05             NA
# GCA_009669545.1_ASM966954v1_genomic   5.41847e-05             NA
# GCA_009669555.1_ASM966955v1_genomic   5.47035e-05             NA
# GCA_009669565.1_ASM966956v1_genomic    5.4939e-05             NA
# ...                                           ...            ...
# NODE595                                        NA             NA
# NODE596                                        NA             NA
# NODE597                                        NA             NA
# NODE598                                        NA             NA
# NODE599                                        NA             NA
#
#                                     population_rtt_dist   tstv cds_sites  \
# sample
# Reference                                    6.3815e-06     NA        NA
# GCA_009909635.1_ASM990963v1_genomic          9.6582e-06  1.854       216
# GCA_009669545.1_ASM966954v1_genomic         1.15566e-05  1.935       246
# GCA_009669555.1_ASM966955v1_genomic         1.20754e-05  2.119       241
# GCA_009669565.1_ASM966956v1_genomic         1.23109e-05      2       247
# ...                                                 ...    ...       ...
# NODE595                                              NA     NA        NA
# NODE596                                              NA     NA        NA
# NODE597                                              NA     NA        NA
# NODE598                                              NA     NA        NA
# NODE599                                              NA     NA        NA
#
#                                     ns_sites ss_sites ns_ss_ratio other_var  \
# sample
# Reference                                 NA       NA          NA        NA
# GCA_009909635.1_ASM990963v1_genomic      121       51     2.37255         1
# GCA_009669545.1_ASM966954v1_genomic      134       60     2.23333         0
# GCA_009669555.1_ASM966955v1_genomic      133       58      2.2931         0
# GCA_009669565.1_ASM966956v1_genomic      135       60        2.25         0
# ...                                      ...      ...         ...       ...
# NODE595                                   NA       NA          NA        NA
# NODE596                                   NA       NA          NA        NA
# NODE597                                   NA       NA          NA        NA
# NODE598                                   NA       NA          NA        NA
# NODE599                                   NA       NA          NA        NA
#
#                                     other_var_ratio homo_het_sites homo_sites  \
# sample
# Reference                                        NA             NA         NA
# GCA_009909635.1_ASM990963v1_genomic       0.0196078            242        216
# GCA_009669545.1_ASM966954v1_genomic               0            271        246
# GCA_009669555.1_ASM966955v1_genomic               0            258        241
# GCA_009669565.1_ASM966956v1_genomic               0            265        247
# ...                                             ...            ...        ...
# NODE595                                          NA             NA         NA
# NODE596                                          NA             NA         NA
# NODE597                                          NA             NA         NA
# NODE598                                          NA             NA         NA
# NODE599                                          NA             NA         NA
#
#                                     het_sites  het_ratio  \
# sample
# Reference                                  NA         NA
# GCA_009909635.1_ASM990963v1_genomic        26   0.107438
# GCA_009669545.1_ASM966954v1_genomic        25  0.0922509
# GCA_009669555.1_ASM966955v1_genomic        17  0.0658915
# GCA_009669565.1_ASM966956v1_genomic        18  0.0679245
# ...                                       ...        ...
# NODE595                                    NA         NA
# NODE596                                    NA         NA
# NODE597                                    NA         NA
# NODE598                                    NA         NA
# NODE599                                    NA         NA
#
#                                     external_branch_length variant_qc  \
# sample
# Reference                                       4.0046e-06       pass
# GCA_009909635.1_ASM990963v1_genomic             2.1201e-06       pass
# GCA_009669545.1_ASM966954v1_genomic                      0       pass
# GCA_009669555.1_ASM966955v1_genomic              2.356e-07       pass
# GCA_009669565.1_ASM966956v1_genomic              4.711e-07       pass
# ...                                                    ...        ...
# NODE595                                                 NA         NA
# NODE596                                                 NA         NA
# NODE597                                                 NA         NA
# NODE598                                                 NA         NA
# NODE599                                                 NA         NA
#
#                                     tstv_outlier node_type  branch_length  \
# sample
# Reference                                      0  terminal   4.004600e-06
# GCA_009909635.1_ASM990963v1_genomic            0  terminal   2.120100e-06
# GCA_009669545.1_ASM966954v1_genomic            0  terminal   0.000000e+00
# GCA_009669555.1_ASM966955v1_genomic            0  terminal   2.356000e-07
# GCA_009669565.1_ASM966956v1_genomic            0  terminal   4.711000e-07
# ...                                          ...       ...            ...
# NODE595                                       NA  internal   2.207000e-07
# NODE596                                       NA  internal   2.356000e-07
# NODE597                                       NA  internal   2.921000e-07
# NODE598                                       NA  internal   5.010000e-08
# NODE599                                       NA  internal   2.248000e-07
#
#                                      branch_support branch_support_conf_char  \
# sample
# Reference                                       0.0
# GCA_009909635.1_ASM990963v1_genomic             0.0
# GCA_009669545.1_ASM966954v1_genomic             0.0
# GCA_009669555.1_ASM966955v1_genomic             0.0
# GCA_009669565.1_ASM966956v1_genomic             0.0
# ...                                             ...                      ...
# NODE595                                        13.0
# NODE596                                        13.0
# NODE597                                        46.0
# NODE598                                        34.0
# NODE599                                        58.0
#
#                                     branch_support_conf_category  \
# sample
# Reference                                                    LOW
# GCA_009909635.1_ASM990963v1_genomic                          LOW
# GCA_009669545.1_ASM966954v1_genomic                          LOW
# GCA_009669555.1_ASM966955v1_genomic                          LOW
# GCA_009669565.1_ASM966956v1_genomic                          LOW
# ...                                                          ...
# NODE595                                                      LOW
# NODE596                                                      LOW
# NODE597                                                      LOW
# NODE598                                                      LOW
# NODE599                                                      LOW
#
#                                     timetree_date timetree_CI_height  \
# sample
# Reference                                     -29                 NA
# GCA_009909635.1_ASM990963v1_genomic           -98                 NA
# GCA_009669545.1_ASM966954v1_genomic           -15                 NA
# GCA_009669555.1_ASM966955v1_genomic           -16                 NA
# GCA_009669565.1_ASM966956v1_genomic           -16                 NA
# ...                                           ...                ...
# NODE595                                  -111.576  {89.1935,137.589}
# NODE596                                  -111.576  {89.1935,137.589}
# NODE597                                  -78.3728  {50.8548,116.815}
# NODE598                                   -70.382     {40.845,106.6}
# NODE599                                  -54.3879   {27.1416,88.513}
#
#                                         timetree_CI_date  \
# sample
# Reference                                             NA
# GCA_009909635.1_ASM990963v1_genomic                   NA
# GCA_009669545.1_ASM966954v1_genomic                   NA
# GCA_009669555.1_ASM966955v1_genomic                   NA
# GCA_009669565.1_ASM966956v1_genomic                   NA
# ...                                                  ...
# NODE595                              {-137.589,-89.1935}
# NODE596                              {-137.589,-89.1935}
# NODE597                              {-116.815,-50.8548}
# NODE598                                 {-106.6,-40.845}
# NODE599                               {-88.513,-27.1416}
#
#                                             mugration_country  \
# sample
# Reference                            United States of America
# GCA_009909635.1_ASM990963v1_genomic                    Russia
# GCA_009669545.1_ASM966954v1_genomic                     China
# GCA_009669555.1_ASM966955v1_genomic                     China
# GCA_009669565.1_ASM966956v1_genomic                     China
# ...                                                       ...
# NODE595                                                  Peru
# NODE596                                                  Peru
# NODE597                                                  Peru
# NODE598                                                  Peru
# NODE599                                                  Peru
#
#                                     mugration_province mugration_continent  \
# sample
# Reference                                     Colorado       North America
# GCA_009909635.1_ASM990963v1_genomic      Rostov Oblast              Europe
# GCA_009669545.1_ASM966954v1_genomic           Xinjiang                Asia
# GCA_009669555.1_ASM966955v1_genomic           Xinjiang                Asia
# GCA_009669565.1_ASM966956v1_genomic           Xinjiang                Asia
# ...                                                ...                 ...
# NODE595                                      Cajamarca       South America
# NODE596                                      Cajamarca       South America
# NODE597                                      Cajamarca       South America
# NODE598                                      Cajamarca       South America
# NODE599                                      Cajamarca       South America
#
#                                     mugration_host_order mugration_population
# sample
# Reference                                          Human                1.ORI
# GCA_009909635.1_ASM990963v1_genomic                Human                2.MED
# GCA_009669545.1_ASM966954v1_genomic             Rodentia                0.ANT
# GCA_009669555.1_ASM966955v1_genomic         Siphonaptera                0.ANT
# GCA_009669565.1_ASM966956v1_genomic             Rodentia                0.ANT
# ...                                                  ...                  ...
# NODE595                                            Human                1.ORI
# NODE596                                         Rodentia                1.ORI
# NODE597                                         Rodentia                1.ORI
# NODE598                                            Human                1.ORI
# NODE599                                         Rodentia                1.ORI
#
# [1201 rows x 59 columns]

# %% [markdown]
# ## Add Mugration Confidence and Handle Root

# %%
df_list = [mug_dict[attr]["conf_df"] for attr in mug_dict]

for df,attr in zip(df_list, MUG_ATTRIBUTE_LIST):
    for sample in df.index:
        max_state = ""
        max_val = 0        
        for state,val in zip(df.columns, df.loc[sample]):
            if val >= max_val:
                max_val = val
                max_state = state
                
        metadata_df.at[sample,"mugration_" + attr] = max_state   
        metadata_df.at[sample,"mugration_" + attr + "_confidence"] = round(max_val, 2)
        
        #if the attr is country or province, extend this confidence to lat and lon
        if attr == "country" or attr == "province":
            metadata_df.at[sample,"mugration_" + attr + "_lat_confidence"] = max_val
            metadata_df.at[sample,"mugration_" + attr + "_lon_confidence"] = max_val

display(metadata_df.loc["NODE0"])

print(metadata_df.loc["NODE0"]["mugration_country_confidence"])
# Out:
# strain                                     NA
# date                                       NA
# date_bp                                    NA
# country                                    NA
# province                                   NA
#                                        ...
# mugration_province_lat_confidence    0.561953
# mugration_province_lon_confidence    0.561953
# mugration_continent_confidence           0.52
# mugration_host_order_confidence          0.93
# mugration_population_confidence           0.5
# Name: NODE0, Length: 68, dtype: object
# 0.85

# %% [markdown]
# ## Latitude and Longtitude

# %%
latlon_country_df = pd.DataFrame()
latlon_province_df = pd.DataFrame()

df_list = [latlon_country_df, latlon_province_df]
attr_list = ["country", "province"]
conf_df_list = [mug_dict["country"]["conf_df"], mug_dict["province"]["conf_df"]]

# Create a mapping of geo name to lat,lon
for df,attr in zip(df_list, attr_list):
    # Get data
    for rec in metadata_df.iterrows():
        node_name = rec[0]
        node_type = rec[1]["node_type"]
        name = rec[1][attr]
        country = rec[1]["country"]
        
        if node_type == "internal":
            continue
        
        if attr == "province" and name == NO_DATA_CHAR and node_type == "terminal" and country != "Russia":
            # Use country instead
            name = rec[1]["country"]
            lat = rec[1]["country_lat"]
            lon = rec[1]["country_lon"]
        else:
            lat = rec[1][attr + "_lat"]
            lon = rec[1][attr + "_lon"]             


        if name not in df.index:
            df.at[name, "lat"] = lat
            df.at[name, "lon"] = lon
            df.at[name, "size"] = 1
        else:
            df["size"][name] += 1

#display(latlon_country_df)
#display(latlon_province_df)


# Update lat lon for mugration
for latlon_df, conf_df, attr in zip(df_list, conf_df_list, attr_list):
    for rec in metadata_df.iterrows():
        sample = rec[0]
        name = rec[1]["mugration_" + attr]  
        node_type = rec[1]["node_type"]  
        country = rec[1]["country"]  
        
        if attr == "province" and rec[1][attr]  == NO_DATA_CHAR and node_type == "terminal" and country != "Russia":
            # Use country instead
            name = rec[1]["country"]
            metadata_df.at[sample,"mugration_" + attr] = name
        
        lat = latlon_df["lat"][name]
        lon = latlon_df["lon"][name]
        
                
        metadata_df.at[sample, "mugration_" + attr +"_lat"] = lat
        metadata_df.at[sample, "mugration_" + attr +"_lon"] = lon
        
        
# Mapping file for auspice
out_path_latlon = os.path.join(augur_dir, "latlon.tsv")

# Countries
with open(out_path_latlon, "w") as outfile:
    for country in latlon_country_df.index:
        lat = str(latlon_country_df["lat"][country])
        lon = str(latlon_country_df["lon"][country])
        outfile.write("country" + "\t" + country + "\t" + lat + "\t" + lon + "\n")
# Provinces
with open(out_path_latlon, "a") as outfile:
    for province in latlon_province_df.index:
        lat = str(latlon_province_df["lat"][province])
        lon = str(latlon_province_df["lon"][province])
        outfile.write("province" + "\t" + province + "\t" + lat + "\t" + lon + "\n")
        
#display(metadata_df[metadata_df["continent"] == "Africa"])

# %% [markdown]
# ## Add Sub  and Spread Rate

# %%
# 1. Get Branch Lengths in Num Substitutions

for c in divtree.find_clades():
    branch_length_sub = c.branch_length * SEQ_LEN
    branch_length_time = timetree.common_ancestor(c.name).branch_length
    walk_path = [divtree.root] + divtree.get_path(c)
    # Root
    if len(walk_path) == 1:
        parent = walk_path[0]
    else:
        parent = walk_path[-2]


    # 1. Rate as subs/site/year
    rate_sub = c.branch_length / branch_length_time  if branch_length_time != 0 else 0
    # 2. Rate as subs/year
    rate_sub_year = branch_length_sub / branch_length_time  if branch_length_time != 0 else 0
    
    metadata_df.at[c.name,"branch_length_sub"] = branch_length_sub
    metadata_df.at[c.name,"branch_length_time"] = branch_length_time
    metadata_df.at[c.name,"rate_sub"] = rate_sub
    metadata_df.at[c.name,"rate_sub_year"] = rate_sub_year

metadata_df.fillna(NO_DATA_CHAR, inplace=True)
display(metadata_df)
# Out:
#                                     strain    date date_bp  \
# sample
# Reference                             CO92    1992     -29
# GCA_009909635.1_ASM990963v1_genomic   9_10  1923.0     -98
# GCA_009669545.1_ASM966954v1_genomic  42126  2006.0     -15
# GCA_009669555.1_ASM966955v1_genomic  42123  2005.0     -16
# GCA_009669565.1_ASM966956v1_genomic  42118  2005.0     -16
# ...                                    ...     ...     ...
# NODE595                                 NA      NA      NA
# NODE596                                 NA      NA      NA
# NODE597                                 NA      NA      NA
# NODE598                                 NA      NA      NA
# NODE599                                 NA      NA      NA
#
#                                                       country       province  \
# sample
# Reference                            United States of America       Colorado
# GCA_009909635.1_ASM990963v1_genomic                    Russia  Rostov Oblast
# GCA_009669545.1_ASM966954v1_genomic                     China       Xinjiang
# GCA_009669555.1_ASM966955v1_genomic                     China       Xinjiang
# GCA_009669565.1_ASM966956v1_genomic                     China       Xinjiang
# ...                                                       ...            ...
# NODE595                                                    NA             NA
# NODE596                                                    NA             NA
# NODE597                                                    NA             NA
# NODE598                                                    NA             NA
# NODE599                                                    NA             NA
#
#                                     country_lat country_lon province_lat  \
# sample
# Reference                               39.7837    -100.446      38.7252
# GCA_009909635.1_ASM990963v1_genomic     64.6863     97.7453      47.6222
# GCA_009669545.1_ASM966954v1_genomic     35.0001         105      42.4805
# GCA_009669555.1_ASM966955v1_genomic     35.0001         105      42.4805
# GCA_009669565.1_ASM966956v1_genomic     35.0001         105      42.4805
# ...                                         ...         ...          ...
# NODE595                                      NA          NA           NA
# NODE596                                      NA          NA           NA
# NODE597                                      NA          NA           NA
# NODE598                                      NA          NA           NA
# NODE599                                      NA          NA           NA
#
#                                     province_lon      biovar branch_major  \
# sample
# Reference                               -105.608  Orientalis        1.ORI
# GCA_009909635.1_ASM990963v1_genomic      40.7958  Medievalis        2.MED
# GCA_009669545.1_ASM966954v1_genomic      85.4633     Antiqua        0.ANT
# GCA_009669555.1_ASM966955v1_genomic      85.4633     Antiqua        0.ANT
# GCA_009669565.1_ASM966956v1_genomic      85.4633     Antiqua        0.ANT
# ...                                          ...         ...          ...
# NODE595                                       NA          NA           NA
# NODE596                                       NA          NA           NA
# NODE597                                       NA          NA           NA
# NODE598                                       NA          NA           NA
# NODE599                                       NA          NA           NA
#
#                                     branch_minor biosample_accession  \
# sample
# Reference                                 1.ORI1        SAMEA1705942
# GCA_009909635.1_ASM990963v1_genomic       2.MED1        SAMN13632815
# GCA_009669545.1_ASM966954v1_genomic       0.ANT1        SAMN07722925
# GCA_009669555.1_ASM966955v1_genomic       0.ANT1        SAMN07722924
# GCA_009669565.1_ASM966956v1_genomic       0.ANT1        SAMN07722923
# ...                                          ...                 ...
# NODE595                                       NA                  NA
# NODE596                                       NA                  NA
# NODE597                                       NA                  NA
# NODE598                                       NA                  NA
# NODE599                                       NA                  NA
#
#                                                    biosample_comment  \
# sample
# Reference                            KEEP: Assembly Modern Reference
# GCA_009909635.1_ASM990963v1_genomic            KEEP: Assembly Modern
# GCA_009669545.1_ASM966954v1_genomic            KEEP: Assembly Modern
# GCA_009669555.1_ASM966955v1_genomic            KEEP: Assembly Modern
# GCA_009669565.1_ASM966956v1_genomic            KEEP: Assembly Modern
# ...                                                              ...
# NODE595                                                           NA
# NODE596                                                           NA
# NODE597                                                           NA
# NODE598                                                           NA
# NODE599                                                           NA
#
#                                     branch_number      continent date_mean  \
# sample
# Reference                                       1  North America      1992
# GCA_009909635.1_ASM990963v1_genomic             2         Europe      1923
# GCA_009669545.1_ASM966954v1_genomic             0           Asia      2006
# GCA_009669555.1_ASM966955v1_genomic             0           Asia      2005
# GCA_009669565.1_ASM966956v1_genomic             0           Asia      2005
# ...                                           ...            ...       ...
# NODE595                                        NA             NA        NA
# NODE596                                        NA             NA        NA
# NODE597                                        NA             NA        NA
# NODE598                                        NA             NA        NA
# NODE599                                        NA             NA        NA
#
#                                     date_bp_mean date_err      lat      lon  \
# sample
# Reference                                     29        0  38.7252 -105.608
# GCA_009909635.1_ASM990963v1_genomic           98        0  47.6222  40.7958
# GCA_009669545.1_ASM966954v1_genomic           15        0  42.4805  85.4633
# GCA_009669555.1_ASM966955v1_genomic           16        0  42.4805  85.4633
# GCA_009669565.1_ASM966956v1_genomic           16        0  42.4805  85.4633
# ...                                          ...      ...      ...      ...
# NODE595                                       NA       NA       NA       NA
# NODE596                                       NA       NA       NA       NA
# NODE597                                       NA       NA       NA       NA
# NODE598                                       NA       NA       NA       NA
# NODE599                                       NA       NA       NA       NA
#
#                                     host_human sequencing_technology  \
# sample
# Reference                                Human                    NA
# GCA_009909635.1_ASM990963v1_genomic      Human            IonTorrent
# GCA_009669545.1_ASM966954v1_genomic  Non-Human   Illumina Hiseq 2000
# GCA_009669555.1_ASM966955v1_genomic  Non-Human   Illumina Hiseq 2000
# GCA_009669565.1_ASM966956v1_genomic  Non-Human   Illumina Hiseq 2000
# ...                                        ...                   ...
# NODE595                                     NA                    NA
# NODE596                                     NA                    NA
# NODE597                                     NA                    NA
# NODE598                                     NA                    NA
# NODE599                                     NA                    NA
#
#                                         assembly_method  \
# sample
# Reference                                            NA
# GCA_009909635.1_ASM990963v1_genomic      Newbler v. 2.6
# GCA_009669545.1_ASM966954v1_genomic  SOAPdenovo v. 2.04
# GCA_009669555.1_ASM966955v1_genomic  SOAPdenovo v. 2.04
# GCA_009669565.1_ASM966956v1_genomic  SOAPdenovo v. 2.04
# ...                                                 ...
# NODE595                                              NA
# NODE596                                              NA
# NODE597                                              NA
# NODE598                                              NA
# NODE599                                              NA
#
#                                                    host_raw    host_order  \
# sample
# Reference                                             Human         Human
# GCA_009909635.1_ASM990963v1_genomic            Homo sapiens         Human
# GCA_009669545.1_ASM966954v1_genomic      Citellus undulatus      Rodentia
# GCA_009669555.1_ASM966955v1_genomic  Frontopsylla elatoides  Siphonaptera
# GCA_009669565.1_ASM966956v1_genomic      Citellus undulatus      Rodentia
# ...                                                     ...           ...
# NODE595                                                  NA            NA
# NODE596                                                  NA            NA
# NODE597                                                  NA            NA
# NODE598                                                  NA            NA
# NODE599                                                  NA            NA
#
#                                     population_color population  \
# sample
# Reference                                    #ff0000      1.ORI
# GCA_009909635.1_ASM990963v1_genomic          #c5e88a      2.MED
# GCA_009669545.1_ASM966954v1_genomic          #238af5      0.ANT
# GCA_009669555.1_ASM966955v1_genomic          #238af5      0.ANT
# GCA_009669565.1_ASM966956v1_genomic          #238af5      0.ANT
# ...                                              ...        ...
# NODE595                                           NA         NA
# NODE596                                           NA         NA
# NODE597                                           NA         NA
# NODE598                                           NA         NA
# NODE599                                           NA         NA
#
#                                                                  geometry  \
# sample
# Reference                                  POINT (-105.607716 38.7251776)
# GCA_009909635.1_ASM990963v1_genomic         POINT (40.7957942 47.6222451)
# GCA_009669545.1_ASM966954v1_genomic  POINT (85.46334640000001 42.4804953)
# GCA_009669555.1_ASM966955v1_genomic  POINT (85.46334640000001 42.4804953)
# GCA_009669565.1_ASM966956v1_genomic  POINT (85.46334640000001 42.4804953)
# ...                                                                   ...
# NODE595                                                                NA
# NODE596                                                                NA
# NODE597                                                                NA
# NODE598                                                                NA
# NODE599                                                                NA
#
#                                     root_rtt_dist clade_rtt_dist  \
# sample
# Reference                             7.31686e-05             NA
# GCA_009909635.1_ASM990963v1_genomic   7.30501e-05             NA
# GCA_009669545.1_ASM966954v1_genomic   5.41847e-05             NA
# GCA_009669555.1_ASM966955v1_genomic   5.47035e-05             NA
# GCA_009669565.1_ASM966956v1_genomic    5.4939e-05             NA
# ...                                           ...            ...
# NODE595                                        NA             NA
# NODE596                                        NA             NA
# NODE597                                        NA             NA
# NODE598                                        NA             NA
# NODE599                                        NA             NA
#
#                                     population_rtt_dist   tstv cds_sites  \
# sample
# Reference                                    6.3815e-06     NA        NA
# GCA_009909635.1_ASM990963v1_genomic          9.6582e-06  1.854       216
# GCA_009669545.1_ASM966954v1_genomic         1.15566e-05  1.935       246
# GCA_009669555.1_ASM966955v1_genomic         1.20754e-05  2.119       241
# GCA_009669565.1_ASM966956v1_genomic         1.23109e-05      2       247
# ...                                                 ...    ...       ...
# NODE595                                              NA     NA        NA
# NODE596                                              NA     NA        NA
# NODE597                                              NA     NA        NA
# NODE598                                              NA     NA        NA
# NODE599                                              NA     NA        NA
#
#                                     ns_sites ss_sites ns_ss_ratio other_var  \
# sample
# Reference                                 NA       NA          NA        NA
# GCA_009909635.1_ASM990963v1_genomic      121       51     2.37255         1
# GCA_009669545.1_ASM966954v1_genomic      134       60     2.23333         0
# GCA_009669555.1_ASM966955v1_genomic      133       58      2.2931         0
# GCA_009669565.1_ASM966956v1_genomic      135       60        2.25         0
# ...                                      ...      ...         ...       ...
# NODE595                                   NA       NA          NA        NA
# NODE596                                   NA       NA          NA        NA
# NODE597                                   NA       NA          NA        NA
# NODE598                                   NA       NA          NA        NA
# NODE599                                   NA       NA          NA        NA
#
#                                     other_var_ratio homo_het_sites homo_sites  \
# sample
# Reference                                        NA             NA         NA
# GCA_009909635.1_ASM990963v1_genomic       0.0196078            242        216
# GCA_009669545.1_ASM966954v1_genomic               0            271        246
# GCA_009669555.1_ASM966955v1_genomic               0            258        241
# GCA_009669565.1_ASM966956v1_genomic               0            265        247
# ...                                             ...            ...        ...
# NODE595                                          NA             NA         NA
# NODE596                                          NA             NA         NA
# NODE597                                          NA             NA         NA
# NODE598                                          NA             NA         NA
# NODE599                                          NA             NA         NA
#
#                                     het_sites  het_ratio  \
# sample
# Reference                                  NA         NA
# GCA_009909635.1_ASM990963v1_genomic        26   0.107438
# GCA_009669545.1_ASM966954v1_genomic        25  0.0922509
# GCA_009669555.1_ASM966955v1_genomic        17  0.0658915
# GCA_009669565.1_ASM966956v1_genomic        18  0.0679245
# ...                                       ...        ...
# NODE595                                    NA         NA
# NODE596                                    NA         NA
# NODE597                                    NA         NA
# NODE598                                    NA         NA
# NODE599                                    NA         NA
#
#                                     external_branch_length variant_qc  \
# sample
# Reference                                       4.0046e-06       pass
# GCA_009909635.1_ASM990963v1_genomic             2.1201e-06       pass
# GCA_009669545.1_ASM966954v1_genomic                      0       pass
# GCA_009669555.1_ASM966955v1_genomic              2.356e-07       pass
# GCA_009669565.1_ASM966956v1_genomic              4.711e-07       pass
# ...                                                    ...        ...
# NODE595                                                 NA         NA
# NODE596                                                 NA         NA
# NODE597                                                 NA         NA
# NODE598                                                 NA         NA
# NODE599                                                 NA         NA
#
#                                     tstv_outlier node_type  branch_length  \
# sample
# Reference                                      0  terminal   4.004600e-06
# GCA_009909635.1_ASM990963v1_genomic            0  terminal   2.120100e-06
# GCA_009669545.1_ASM966954v1_genomic            0  terminal   0.000000e+00
# GCA_009669555.1_ASM966955v1_genomic            0  terminal   2.356000e-07
# GCA_009669565.1_ASM966956v1_genomic            0  terminal   4.711000e-07
# ...                                          ...       ...            ...
# NODE595                                       NA  internal   2.207000e-07
# NODE596                                       NA  internal   2.356000e-07
# NODE597                                       NA  internal   2.921000e-07
# NODE598                                       NA  internal   5.010000e-08
# NODE599                                       NA  internal   2.248000e-07
#
#                                      branch_support branch_support_conf_char  \
# sample
# Reference                                       0.0
# GCA_009909635.1_ASM990963v1_genomic             0.0
# GCA_009669545.1_ASM966954v1_genomic             0.0
# GCA_009669555.1_ASM966955v1_genomic             0.0
# GCA_009669565.1_ASM966956v1_genomic             0.0
# ...                                             ...                      ...
# NODE595                                        13.0
# NODE596                                        13.0
# NODE597                                        46.0
# NODE598                                        34.0
# NODE599                                        58.0
#
#                                     branch_support_conf_category  \
# sample
# Reference                                                    LOW
# GCA_009909635.1_ASM990963v1_genomic                          LOW
# GCA_009669545.1_ASM966954v1_genomic                          LOW
# GCA_009669555.1_ASM966955v1_genomic                          LOW
# GCA_009669565.1_ASM966956v1_genomic                          LOW
# ...                                                          ...
# NODE595                                                      LOW
# NODE596                                                      LOW
# NODE597                                                      LOW
# NODE598                                                      LOW
# NODE599                                                      LOW
#
#                                     timetree_date timetree_CI_height  \
# sample
# Reference                                     -29                 NA
# GCA_009909635.1_ASM990963v1_genomic           -98                 NA
# GCA_009669545.1_ASM966954v1_genomic           -15                 NA
# GCA_009669555.1_ASM966955v1_genomic           -16                 NA
# GCA_009669565.1_ASM966956v1_genomic           -16                 NA
# ...                                           ...                ...
# NODE595                                  -111.576  {89.1935,137.589}
# NODE596                                  -111.576  {89.1935,137.589}
# NODE597                                  -78.3728  {50.8548,116.815}
# NODE598                                   -70.382     {40.845,106.6}
# NODE599                                  -54.3879   {27.1416,88.513}
#
#                                         timetree_CI_date  \
# sample
# Reference                                             NA
# GCA_009909635.1_ASM990963v1_genomic                   NA
# GCA_009669545.1_ASM966954v1_genomic                   NA
# GCA_009669555.1_ASM966955v1_genomic                   NA
# GCA_009669565.1_ASM966956v1_genomic                   NA
# ...                                                  ...
# NODE595                              {-137.589,-89.1935}
# NODE596                              {-137.589,-89.1935}
# NODE597                              {-116.815,-50.8548}
# NODE598                                 {-106.6,-40.845}
# NODE599                               {-88.513,-27.1416}
#
#                                             mugration_country  \
# sample
# Reference                            United States of America
# GCA_009909635.1_ASM990963v1_genomic                    Russia
# GCA_009669545.1_ASM966954v1_genomic                     China
# GCA_009669555.1_ASM966955v1_genomic                     China
# GCA_009669565.1_ASM966956v1_genomic                     China
# ...                                                       ...
# NODE595                                                  Peru
# NODE596                                                  Peru
# NODE597                                                  Peru
# NODE598                                                  Peru
# NODE599                                                  Peru
#
#                                     mugration_province mugration_continent  \
# sample
# Reference                                     Colorado       North America
# GCA_009909635.1_ASM990963v1_genomic      Rostov Oblast              Europe
# GCA_009669545.1_ASM966954v1_genomic           Xinjiang                Asia
# GCA_009669555.1_ASM966955v1_genomic           Xinjiang                Asia
# GCA_009669565.1_ASM966956v1_genomic           Xinjiang                Asia
# ...                                                ...                 ...
# NODE595                                      Cajamarca       South America
# NODE596                                      Cajamarca       South America
# NODE597                                      Cajamarca       South America
# NODE598                                      Cajamarca       South America
# NODE599                                      Cajamarca       South America
#
#                                     mugration_host_order mugration_population  \
# sample
# Reference                                          Human                1.ORI
# GCA_009909635.1_ASM990963v1_genomic                Human                2.MED
# GCA_009669545.1_ASM966954v1_genomic             Rodentia                0.ANT
# GCA_009669555.1_ASM966955v1_genomic         Siphonaptera                0.ANT
# GCA_009669565.1_ASM966956v1_genomic             Rodentia                0.ANT
# ...                                                  ...                  ...
# NODE595                                            Human                1.ORI
# NODE596                                         Rodentia                1.ORI
# NODE597                                         Rodentia                1.ORI
# NODE598                                            Human                1.ORI
# NODE599                                         Rodentia                1.ORI
#
#                                      mugration_country_confidence  \
# sample
# Reference                                                     1.0
# GCA_009909635.1_ASM990963v1_genomic                           1.0
# GCA_009669545.1_ASM966954v1_genomic                           1.0
# GCA_009669555.1_ASM966955v1_genomic                           1.0
# GCA_009669565.1_ASM966956v1_genomic                           1.0
# ...                                                           ...
# NODE595                                                       1.0
# NODE596                                                       1.0
# NODE597                                                       1.0
# NODE598                                                       1.0
# NODE599                                                       1.0
#
#                                      mugration_country_lat_confidence  \
# sample
# Reference                                                    1.000000
# GCA_009909635.1_ASM990963v1_genomic                          1.000000
# GCA_009669545.1_ASM966954v1_genomic                          1.000000
# GCA_009669555.1_ASM966955v1_genomic                          1.000000
# GCA_009669565.1_ASM966956v1_genomic                          1.000000
# ...                                                               ...
# NODE595                                                      0.999999
# NODE596                                                      0.999999
# NODE597                                                      0.999999
# NODE598                                                      0.999999
# NODE599                                                      0.999999
#
#                                      mugration_country_lon_confidence  \
# sample
# Reference                                                    1.000000
# GCA_009909635.1_ASM990963v1_genomic                          1.000000
# GCA_009669545.1_ASM966954v1_genomic                          1.000000
# GCA_009669555.1_ASM966955v1_genomic                          1.000000
# GCA_009669565.1_ASM966956v1_genomic                          1.000000
# ...                                                               ...
# NODE595                                                      0.999999
# NODE596                                                      0.999999
# NODE597                                                      0.999999
# NODE598                                                      0.999999
# NODE599                                                      0.999999
#
#                                      mugration_province_confidence  \
# sample
# Reference                                                     1.00
# GCA_009909635.1_ASM990963v1_genomic                           1.00
# GCA_009669545.1_ASM966954v1_genomic                           1.00
# GCA_009669555.1_ASM966955v1_genomic                           1.00
# GCA_009669565.1_ASM966956v1_genomic                           1.00
# ...                                                            ...
# NODE595                                                       1.00
# NODE596                                                       1.00
# NODE597                                                       1.00
# NODE598                                                       1.00
# NODE599                                                       0.99
#
#                                      mugration_province_lat_confidence  \
# sample
# Reference                                                     1.000000
# GCA_009909635.1_ASM990963v1_genomic                           1.000000
# GCA_009669545.1_ASM966954v1_genomic                           1.000000
# GCA_009669555.1_ASM966955v1_genomic                           1.000000
# GCA_009669565.1_ASM966956v1_genomic                           1.000000
# ...                                                                ...
# NODE595                                                       0.999873
# NODE596                                                       0.999998
# NODE597                                                       0.999999
# NODE598                                                       0.999874
# NODE599                                                       0.991635
#
#                                      mugration_province_lon_confidence  \
# sample
# Reference                                                     1.000000
# GCA_009909635.1_ASM990963v1_genomic                           1.000000
# GCA_009669545.1_ASM966954v1_genomic                           1.000000
# GCA_009669555.1_ASM966955v1_genomic                           1.000000
# GCA_009669565.1_ASM966956v1_genomic                           1.000000
# ...                                                                ...
# NODE595                                                       0.999873
# NODE596                                                       0.999998
# NODE597                                                       0.999999
# NODE598                                                       0.999874
# NODE599                                                       0.991635
#
#                                      mugration_continent_confidence  \
# sample
# Reference                                                       1.0
# GCA_009909635.1_ASM990963v1_genomic                             1.0
# GCA_009669545.1_ASM966954v1_genomic                             1.0
# GCA_009669555.1_ASM966955v1_genomic                             1.0
# GCA_009669565.1_ASM966956v1_genomic                             1.0
# ...                                                             ...
# NODE595                                                         1.0
# NODE596                                                         1.0
# NODE597                                                         1.0
# NODE598                                                         1.0
# NODE599                                                         1.0
#
#                                      mugration_host_order_confidence  \
# sample
# Reference                                                       1.00
# GCA_009909635.1_ASM990963v1_genomic                             1.00
# GCA_009669545.1_ASM966954v1_genomic                             1.00
# GCA_009669555.1_ASM966955v1_genomic                             1.00
# GCA_009669565.1_ASM966956v1_genomic                             1.00
# ...                                                              ...
# NODE595                                                         0.55
# NODE596                                                         0.61
# NODE597                                                         0.56
# NODE598                                                         0.60
# NODE599                                                         0.82
#
#                                      mugration_population_confidence  \
# sample
# Reference                                                        1.0
# GCA_009909635.1_ASM990963v1_genomic                              1.0
# GCA_009669545.1_ASM966954v1_genomic                              1.0
# GCA_009669555.1_ASM966955v1_genomic                              1.0
# GCA_009669565.1_ASM966956v1_genomic                              1.0
# ...                                                              ...
# NODE595                                                          1.0
# NODE596                                                          1.0
# NODE597                                                          1.0
# NODE598                                                          1.0
# NODE599                                                          1.0
#
#                                      mugration_country_lat  \
# sample
# Reference                                        39.783730
# GCA_009909635.1_ASM990963v1_genomic              64.686314
# GCA_009669545.1_ASM966954v1_genomic              35.000074
# GCA_009669555.1_ASM966955v1_genomic              35.000074
# GCA_009669565.1_ASM966956v1_genomic              35.000074
# ...                                                    ...
# NODE595                                          -6.869970
# NODE596                                          -6.869970
# NODE597                                          -6.869970
# NODE598                                          -6.869970
# NODE599                                          -6.869970
#
#                                      mugration_country_lon  \
# sample
# Reference                                      -100.445882
# GCA_009909635.1_ASM990963v1_genomic              97.745306
# GCA_009669545.1_ASM966954v1_genomic             104.999927
# GCA_009669555.1_ASM966955v1_genomic             104.999927
# GCA_009669565.1_ASM966956v1_genomic             104.999927
# ...                                                    ...
# NODE595                                         -75.045851
# NODE596                                         -75.045851
# NODE597                                         -75.045851
# NODE598                                         -75.045851
# NODE599                                         -75.045851
#
#                                      mugration_province_lat  \
# sample
# Reference                                         38.725178
# GCA_009909635.1_ASM990963v1_genomic               47.622245
# GCA_009669545.1_ASM966954v1_genomic               42.480495
# GCA_009669555.1_ASM966955v1_genomic               42.480495
# GCA_009669565.1_ASM966956v1_genomic               42.480495
# ...                                                     ...
# NODE595                                           -6.250000
# NODE596                                           -6.250000
# NODE597                                           -6.250000
# NODE598                                           -6.250000
# NODE599                                           -6.250000
#
#                                      mugration_province_lon  \
# sample
# Reference                                       -105.607716
# GCA_009909635.1_ASM990963v1_genomic               40.795794
# GCA_009669545.1_ASM966954v1_genomic               85.463346
# GCA_009669555.1_ASM966955v1_genomic               85.463346
# GCA_009669565.1_ASM966956v1_genomic               85.463346
# ...                                                     ...
# NODE595                                          -78.833333
# NODE596                                          -78.833333
# NODE597                                          -78.833333
# NODE598                                          -78.833333
# NODE599                                          -78.833333
#
#                                      branch_length_sub  branch_length_time  \
# sample
# Reference                                    16.935846           162.52800
# GCA_009909635.1_ASM990963v1_genomic           8.966111           878.89200
# GCA_009669545.1_ASM966954v1_genomic           0.000000             9.23246
# GCA_009669555.1_ASM966955v1_genomic           0.996375            24.38400
# GCA_009669565.1_ASM966956v1_genomic           1.992328            35.90130
# ...                                                ...                 ...
# NODE595                                       0.933362             0.00000
# NODE596                                       0.996375             0.00000
# NODE597                                       1.235320            33.20350
# NODE598                                       0.211878            41.19420
# NODE599                                       0.950701            15.99410
#
#                                          rate_sub  rate_sub_year
# sample
# Reference                            2.463945e-08       0.104203
# GCA_009909635.1_ASM990963v1_genomic  2.412242e-09       0.010202
# GCA_009669545.1_ASM966954v1_genomic  0.000000e+00       0.000000
# GCA_009669555.1_ASM966955v1_genomic  9.662073e-09       0.040862
# GCA_009669565.1_ASM966956v1_genomic  1.312209e-08       0.055495
# ...                                           ...            ...
# NODE595                              0.000000e+00       0.000000
# NODE596                              0.000000e+00       0.000000
# NODE597                              8.797265e-09       0.037204
# NODE598                              1.216191e-09       0.005143
# NODE599                              1.405518e-08       0.059441
#
# [1201 rows x 76 columns]

# %% [markdown]
# ## Colors

# %%
out_path_colors = os.path.join(augur_dir, "colors.tsv")

## Manual
colors_dict = {}
colors_dict["population"] = {'0.PRE': '#8000ff', '0.PE': '#5148fc', '0.ANT': '#238af5', '0.ANT4': '#0cc1e8', '3.ANT': '#3ae8d7', '4.ANT': '#68fcc1', '2.ANT': '#97fca7', '2.MED': '#c5e88a', '1.PRE': '#f3c16a', '1.ANT': '#ff8a48', '1.IN': '#ff4824', '1.ORI': '#ff0000', 'NA': '#c4c4c4'}
colors_dict["population_raw"] = {'0.PRE': '#8000ff', '0.PE': '#5148fc', '0.ANT': '#238af5', '0.ANT4': '#0cc1e8', '3.ANT': '#3ae8d7', '4.ANT': '#68fcc1', '2.ANT': '#97fca7', '2.MED': '#c5e88a', '1.PRE': '#f3c16a', '1.ANT': '#ff8a48', '1.IN': '#ff4824', '1.ORI': '#ff0000', 'NA': '#c4c4c4'}


no_data_color = "#FFFFFF"
#neutral_color = "#9A9A9A"
#neutral_color = "#383838"
neutral_color = "#525252"

host_manual_color = {
    # Rodent is baseline
    'rodentia': neutral_color, 
    'human': '#d62728', 
    # Other mammals
    'marsupialia': "#1f77b4",
    'artiodactyla': "#1f77b4", 
    'carnivora': "#1f77b4", 
    'lagomorpha': "#1f77b4", 
    # Insects
    'siphonaptera': "#2ca02c", 
    'phthiraptera': "#2ca02c", 
    'ixodida': "#2ca02c", 
    'lepidoptera': "#2ca02c", 
    # Other
    'na': no_data_color,     
}

for attr in mug_dict:
    if attr in colors_dict:
        continue
    # Create the color map
    colors_dict[attr] = {}
    colors_dict[attr + "_raw"] = {}
    
    for t in divtree.get_terminals():
        attr_val = metadata_df[attr][t.name].lower()
        
        # Initialize stats and values
        if attr_val not in colors_dict[attr] and attr_val != NO_DATA_CHAR:
            colors_dict[attr][attr_val] = ""

    if attr != "host_order":
        # Create the custom color map (pyplot)
        cmap = plt.get_cmap("rainbow", len(colors_dict[attr]))
        # Convert the color map to a list of RGB values
        cmaplist = [cmap(i) for i in range(cmap.N)]
        # Convert RGB values to hex colors
        attr_hex = [colors.to_hex(col) for col in cmaplist]
    
    else:
        attr_hex = []
        for attr_val in colors_dict[attr]:
            attr_col = host_manual_color[attr_val]
            attr_hex.append(attr_col)
    
    # Assign colors to value
    for attr_val, attr_col in zip(colors_dict[attr], attr_hex):
        colors_dict[attr][attr_val] = attr_col
        colors_dict[attr + "_raw"][attr_val] = attr_col
        
    # Add unknown
    #colors_dict[attr][UNKNOWN_CHAR] = no_data_color
    #colors_dict[attr + "_raw"][UNKNOWN_CHAR] = no_data_color
    
print(colors_dict)

print(out_path_colors)

with open(out_path_colors, "w") as outfile:
    for attr_key in colors_dict:
        for attr_val in colors_dict[attr_key]:
            line = str(attr_key) + "\t" + str(attr_val) + "\t" + str(colors_dict[attr_key][attr_val])
            print(line)
            outfile.write(line + "\n")
# Out:
# {'population': {'0.PRE': '#8000ff', '0.PE': '#5148fc', '0.ANT': '#238af5', '0.ANT4': '#0cc1e8', '3.ANT': '#3ae8d7', '4.ANT': '#68fcc1', '2.ANT': '#97fca7', '2.MED': '#c5e88a', '1.PRE': '#f3c16a', '1.ANT': '#ff8a48', '1.IN': '#ff4824', '1.ORI': '#ff0000', 'NA': '#c4c4c4'}, 'population_raw': {'0.PRE': '#8000ff', '0.PE': '#5148fc', '0.ANT': '#238af5', '0.ANT4': '#0cc1e8', '3.ANT': '#3ae8d7', '4.ANT': '#68fcc1', '2.ANT': '#97fca7', '2.MED': '#c5e88a', '1.PRE': '#f3c16a', '1.ANT': '#ff8a48', '1.IN': '#ff4824', '1.ORI': '#ff0000', 'NA': '#c4c4c4'}, 'country': {'russia': '#8000ff', 'lithuania': '#7215ff', 'estonia': '#652afe', 'germany': '#573ffd', 'china': '#4a53fc', 'azerbaijan': '#3c66fa', 'armenia': '#2f79f7', 'georgia': '#228bf4', 'mongolia': '#149df1', 'tajikistan': '#07adee', 'kyrgyzstan': '#07bcea', 'england': '#14c9e5', 'spain': '#22d5e0', 'france': '#2fe0db', 'nepal': '#3cead5', 'india': '#4af1d0', 'kazakhstan': '#57f7c9', 'turkmenistan': '#65fcc3', 'uzbekistan': '#72febc', 'iran': '#80ffb4', 'italy': '#8dfead', 'poland': '#9afca5', 'switzerland': '#a8f79d', 'norway': '#b5f194', 'the netherlands': '#c3ea8b', 'kenya': '#d0e083', 'uganda': '#ddd579', 'democratic republic of the congo': '#ebc970', 'vietnam': '#f8bc66', 'myanmar': '#ffad5d', 'united states of america': '#ff9d53', 'peru': '#ff8b49', 'canada': '#ff793f', 'indonesia': '#ff6634', 'madagascar': '#ff532a', 'zimbabwe': '#ff3f20', 'algeria': '#ff2a15', 'brazil': '#ff150b', 'bolivia': '#ff0000'}, 'country_raw': {'russia': '#8000ff', 'lithuania': '#7215ff', 'estonia': '#652afe', 'germany': '#573ffd', 'china': '#4a53fc', 'azerbaijan': '#3c66fa', 'armenia': '#2f79f7', 'georgia': '#228bf4', 'mongolia': '#149df1', 'tajikistan': '#07adee', 'kyrgyzstan': '#07bcea', 'england': '#14c9e5', 'spain': '#22d5e0', 'france': '#2fe0db', 'nepal': '#3cead5', 'india': '#4af1d0', 'kazakhstan': '#57f7c9', 'turkmenistan': '#65fcc3', 'uzbekistan': '#72febc', 'iran': '#80ffb4', 'italy': '#8dfead', 'poland': '#9afca5', 'switzerland': '#a8f79d', 'norway': '#b5f194', 'the netherlands': '#c3ea8b', 'kenya': '#d0e083', 'uganda': '#ddd579', 'democratic republic of the congo': '#ebc970', 'vietnam': '#f8bc66', 'myanmar': '#ffad5d', 'united states of america': '#ff9d53', 'peru': '#ff8b49', 'canada': '#ff793f', 'indonesia': '#ff6634', 'madagascar': '#ff532a', 'zimbabwe': '#ff3f20', 'algeria': '#ff2a15', 'brazil': '#ff150b', 'bolivia': '#ff0000'}, 'province': {'krasnoyarsk krai': '#8000ff', 'panevezys county': '#7b07ff', 'pärnu maakond': '#760eff', 'irkutsk oblast': '#7216ff', 'bavaria': '#6d1dff', 'altai krai': '#6924fe', 'qinghai': '#642bfe', 'republic of dagestan': '#5f32fe', 'goranboy district': '#5b39fd', 'syunik province': '#5640fd', 'shirak province': '#5247fc', 'gegharkunik province': '#4d4efc', 'samtskhe-javakheti': '#4855fb', 'shahbuz rayon': '#445cfb', 'na': '#3f62fa', 'samara oblast': '#3b69f9', 'sečuán': '#3670f8', 'bayankhongor': '#3176f8', 'inner mongolia': '#2d7cf7', 'sughd province': '#2883f6', 'talas region': '#2489f5', 'altai republic': '#1f8ff4', 'govi-altai': '#1a95f3', 'övörkhangai': '#169bf2', 'ömnögovi': '#11a0f0', 'bayan-ölgii': '#0da6ef', 'khovd': '#08abee', 'xinjiang': '#03b0ed', 'issyk-kul region': '#01b6eb', 'east of england': '#06bbea', 'valencia community': '#0abfe8', 'centre-loire valley': '#0fc4e7', 'osh region': '#14c9e5', 'naryn region': '#18cde4', 'gansu': '#1dd1e2', 'hovsgel': '#21d5e0', 'zavkhan province': '#26d9df', 'dornogovi': '#2adddd', 'tuva republic': '#2fe0db', 'jilin': '#34e4d9', 'st. petersberg': '#38e7d7', 'zabaykalsky krai': '#3dead5', 'heilongjiang': '#41edd3', 'tibet': '#46efd1', 'gandaki pradesh': '#4bf2cf', 'maharashtra': '#4ff4cd', 'himachal pradesh': '#54f6cb', 'kabardino-balkaria': '#58f8c9', 'karachay-cherkessia': '#5df9c6', 'ningxia': '#62fbc4', 'shaanxi': '#66fcc2', 'hebei': '#6bfdbf', 'west kazakhstan region': '#6ffebd', 'nagorno-karabakh republic': '#74febb', 'kyzylorda region': '#79ffb8', 'rostov oblast': '#7dffb6', 'astrakhan oblast': '#82ffb3' ...
# /mnt/c/Users/ktmea/Projects/plague-phylogeography-projects/main/augur/all/chromosome/full/filter5/ml/colors.tsv
# population	0.PRE	#8000ff
# population	0.PE	#5148fc
# population	0.ANT	#238af5
# population	0.ANT4	#0cc1e8
# population	3.ANT	#3ae8d7
# population	4.ANT	#68fcc1
# population	2.ANT	#97fca7
# population	2.MED	#c5e88a
# population	1.PRE	#f3c16a
# population	1.ANT	#ff8a48
# population	1.IN	#ff4824
# population	1.ORI	#ff0000
# population	NA	#c4c4c4
# population_raw	0.PRE	#8000ff
# population_raw	0.PE	#5148fc
# population_raw	0.ANT	#238af5
# population_raw	0.ANT4	#0cc1e8
# population_raw	3.ANT	#3ae8d7
# population_raw	4.ANT	#68fcc1
# population_raw	2.ANT	#97fca7
# population_raw	2.MED	#c5e88a
# population_raw	1.PRE	#f3c16a
# population_raw	1.ANT	#ff8a48
# population_raw	1.IN	#ff4824
# population_raw	1.ORI	#ff0000
# population_raw	NA	#c4c4c4
# country	russia	#8000ff
# country	lithuania	#7215ff
# country	estonia	#652afe
# country	germany	#573ffd
# country	china	#4a53fc
# country	azerbaijan	#3c66fa
# country	armenia	#2f79f7
# country	georgia	#228bf4
# country	mongolia	#149df1
# country	tajikistan	#07adee
# country	kyrgyzstan	#07bcea
# country	england	#14c9e5
# country	spain	#22d5e0
# country	france	#2fe0db
# country	nepal	#3cead5
# country	india	#4af1d0
# country	kazakhstan	#57f7c9
# country	turkmenistan	#65fcc3
# country	uzbekistan	#72febc
# country	iran	#80ffb4
# country	italy	#8dfead
# country	poland	#9afca5
# country	switzerland	#a8f79d
# country	norway	#b5f194
# country	the netherlands	#c3ea8b
# country	kenya	#d0e083
# country	uganda	#ddd579
# country	democratic republic of the congo	#ebc970
# country	vietnam	#f8bc66
# country	myanmar	#ffad5d
# country	united states of america	#ff9d53
# country	peru	#ff8b49
# country	canada	#ff793f
# country	indonesia	#ff6634
# country	madagascar	#ff532a
# country	zimbabwe	#ff3f20
# country	algeria	#ff2a15
# country	brazil	#ff150b
# country	bolivia	#ff0000
# country_raw	russia	#8000ff
# country_raw	lithuania	#7215ff
# country_raw	estonia	#652afe
# country_raw	germany	#573ffd
# country_raw	china	#4a53fc
# country_raw	azerbaijan	#3c66fa
# country_raw	armenia	#2f79f7
# country_raw	georgia	#228bf4
# country_raw	mongolia	#149df1
# country_raw	tajikistan	#07adee
# country_raw	kyrgyzstan	#07bcea
# country_raw	england	#14c9e5
# country_raw	spain	#22d5e0
# country_raw	france	#2fe0db
# country_raw	nepal	#3cead5
# country_raw	india	#4af1d0
# country_raw	kazakhstan	#57f7c9
# country_raw	turkmenistan	#65fcc3
# country_raw	uzbekistan	#72febc
# country_raw	iran	#80ffb4
# country_raw	italy	#8dfead
# country_raw	poland	#9afca5
# country_raw	switzerland	#a8f79d
# country_raw	norway	#b5f194
# country_raw	the netherlands	#c3ea8b
# country_raw	kenya	#d0e083
# country_raw	uganda	#ddd579
# country_raw	democratic republic of the congo	#ebc970
# country_raw	vietnam	#f8bc66
# country_raw	myanmar	#ffad5d
# country_raw	united states of america	#ff9d53
# country_raw	peru	#ff8b49
# country_raw	canada	#ff793f
# country_raw	indonesia	#ff6634
# country_raw	madagascar	#ff532a
# country_raw	zimbabwe	#ff3f20
# country_raw	algeria	#ff2a15
# country_raw	brazil	#ff150b
# country_raw	bolivia	#ff0000
# province	krasnoyarsk krai	#8000ff
# province	panevezys county	#7b07ff
# province	pärnu maakond	#760eff
# province	irkutsk oblast	#7216ff
# province	bavaria	#6d1dff
# province	altai krai	#6924fe
# province	qinghai	#642bfe
# province	republic of dagestan	#5f32fe
# province	goranboy district	#5b39fd
# province	syunik province	#5640fd
# province	shirak province	#5247fc
# province	gegharkunik province	#4d4efc
# province	samtskhe-javakheti	#4855fb
# province	shahbuz rayon	#445cfb
# province	na	#3f62fa
# province	samara oblast	#3b69f9
# province	sečuán	#3670f8
# province	bayankhongor	#3176f8
# province	inner mongolia	#2d7cf7
# province	sughd province	#2883f6
# province	talas region	#2489f5
# province	altai republic	#1f8ff4
# province	govi-altai	#1a95f3
# province	övörkhangai	#169bf2
# province	ömnögovi	#11a0f0
# province	bayan-ölgii	#0da6ef
# province	khovd	#08abee
# province	xinjiang	#03b0ed
# province	issyk-kul region	#01b6eb
# province	east of england	#06bbea
# province	valencia community	#0abfe8
# province	centre-loire valley	#0fc4e7
# province	osh region	#14c9e5
# province	naryn region	#18cde4
# province	gansu	#1dd1e2
# province	hovsgel	#21d5e0
# province	zavkhan province	#26d9df
# province	dornogovi	#2adddd
# province	tuva republic	#2fe0db
# province	jilin	#34e4d9
# province	st. petersberg	#38e7d7
# province	zabaykalsky krai	#3dead5
# province	heilongjiang	#41edd3
# province	tibet	#46efd1
# province	gandaki pradesh	#4bf2cf
# province	maharashtra	#4ff4cd
# province	himachal pradesh	#54f6cb
# province	kabardino-balkaria	#58f8c9
# province	karachay-cherkessia	#5df9c6
# province	ningxia	#62fbc4
# province	shaanxi	#66fcc2
# province	hebei	#6bfdbf
# province	west kazakhstan region	#6ffebd
# province	nagorno-karabakh republic	#74febb
# province	kyzylorda region	#79ffb8
# province	rostov oblast	#7dffb6
# province	astrakhan oblast	#82ffb3
# province	balkan	#86ffb0
# province	shymkent	#8bfeae
# province	navoiy region	#90feab
# province	almaty region	#94fda8
# province	atyrau region	#99fca6
# province	fizuli district	#9dfba3
# province	baku	#a2f9a0
# province	kurdistan	#a7f89d
# province	shamkir district	#abf69b
# province	stavropol krai	#b0f498
# province	ingushetia	#b4f295
# province	mangystau region	#b9ef92
# province	chechnya	#beed8f
# province	aktobe region	#c2ea8c
# province	atyrau	#c7e789
# province	qazakh district	#cbe486
# province	republic of kalmykia	#d0e083
# province	tatarstan	#d4dd80
# province	lazio	#d9d97c
# province	greater london	#ded579
# province	provence-alpes-côte d'azur	#e2d176
# province	baden-württemberg	#e7cd73
# province	vilnius county	#ebc970
# province	pomeranian voivodeship	#f0c46c
# province	brandenburg	#f5bf69
# province	nidwalden	#f9bb66
# province	oslo	#feb662
# province	catalonia	#ffb05f
# province	occitanie	#ffab5c
# province	north brabant	#ffa658
# province	nairobi	#ffa055
# province	yunnan	#ff9b52
# province	khánh hoà province	#ff954e
# province	lâm đồng province	#ff8f4b
# province	ho chi minh city	#ff8947
# province	guangxi zhuang	#ff8344
# province	california	#ff7c40
# province	la libertad	#ff763d
# province	tamil nadu	#ff7039
# province	saskatchewan	#ff6936
# province	arizona	#ff6232
# province	new mexico	#ff5c2f
# province	colorado	#ff552b
# province	texas	#ff4e28
# province	nevada	#ff4724
# province	central java	#ff4020
# province	province de fianarantsoa	#ff391d
# province	kirov oblast	#ff3219
# province	gujarat	#ff2b16
# province	fujian	#ff2412
# province	midlands	#ff1d0e
# province	msila	#ff160b
# province	state of mato grosso	#ff0e07
# province	la paz	#ff0704
# province	cajamarca	#ff0000
# province_raw	krasnoyarsk krai	#8000ff
# province_raw	panevezys county	#7b07ff
# province_raw	pärnu maakond	#760eff
# province_raw	irkutsk oblast	#7216ff
# province_raw	bavaria	#6d1dff
# province_raw	altai krai	#6924fe
# province_raw	qinghai	#642bfe
# province_raw	republic of dagestan	#5f32fe
# province_raw	goranboy district	#5b39fd
# province_raw	syunik province	#5640fd
# province_raw	shirak province	#5247fc
# province_raw	gegharkunik province	#4d4efc
# province_raw	samtskhe-javakheti	#4855fb
# province_raw	shahbuz rayon	#445cfb
# province_raw	na	#3f62fa
# province_raw	samara oblast	#3b69f9
# province_raw	sečuán	#3670f8
# province_raw	bayankhongor	#3176f8
# province_raw	inner mongolia	#2d7cf7
# province_raw	sughd province	#2883f6
# province_raw	talas region	#2489f5
# province_raw	altai republic	#1f8ff4
# province_raw	govi-altai	#1a95f3
# province_raw	övörkhangai	#169bf2
# province_raw	ömnögovi	#11a0f0
# province_raw	bayan-ölgii	#0da6ef
# province_raw	khovd	#08abee
# province_raw	xinjiang	#03b0ed
# province_raw	issyk-kul region	#01b6eb
# province_raw	east of england	#06bbea
# province_raw	valencia community	#0abfe8
# province_raw	centre-loire valley	#0fc4e7
# province_raw	osh region	#14c9e5
# province_raw	naryn region	#18cde4
# province_raw	gansu	#1dd1e2
# province_raw	hovsgel	#21d5e0
# province_raw	zavkhan province	#26d9df
# province_raw	dornogovi	#2adddd
# province_raw	tuva republic	#2fe0db
# province_raw	jilin	#34e4d9
# province_raw	st. petersberg	#38e7d7
# province_raw	zabaykalsky krai	#3dead5
# province_raw	heilongjiang	#41edd3
# province_raw	tibet	#46efd1
# province_raw	gandaki pradesh	#4bf2cf
# province_raw	maharashtra	#4ff4cd
# province_raw	himachal pradesh	#54f6cb
# province_raw	kabardino-balkaria	#58f8c9
# province_raw	karachay-cherkessia	#5df9c6
# province_raw	ningxia	#62fbc4
# province_raw	shaanxi	#66fcc2
# province_raw	hebei	#6bfdbf
# province_raw	west kazakhstan region	#6ffebd
# province_raw	nagorno-karabakh republic	#74febb
# province_raw	kyzylorda region	#79ffb8
# province_raw	rostov oblast	#7dffb6
# province_raw	astrakhan oblast	#82ffb3
# province_raw	balkan	#86ffb0
# province_raw	shymkent	#8bfeae
# province_raw	navoiy region	#90feab
# province_raw	almaty region	#94fda8
# province_raw	atyrau region	#99fca6
# province_raw	fizuli district	#9dfba3
# province_raw	baku	#a2f9a0
# province_raw	kurdistan	#a7f89d
# province_raw	shamkir district	#abf69b
# province_raw	stavropol krai	#b0f498
# province_raw	ingushetia	#b4f295
# province_raw	mangystau region	#b9ef92
# province_raw	chechnya	#beed8f
# province_raw	aktobe region	#c2ea8c
# province_raw	atyrau	#c7e789
# province_raw	qazakh district	#cbe486
# province_raw	republic of kalmykia	#d0e083
# province_raw	tatarstan	#d4dd80
# province_raw	lazio	#d9d97c
# province_raw	greater london	#ded579
# province_raw	provence-alpes-côte d'azur	#e2d176
# province_raw	baden-württemberg	#e7cd73
# province_raw	vilnius county	#ebc970
# province_raw	pomeranian voivodeship	#f0c46c
# province_raw	brandenburg	#f5bf69
# province_raw	nidwalden	#f9bb66
# province_raw	oslo	#feb662
# province_raw	catalonia	#ffb05f
# province_raw	occitanie	#ffab5c
# province_raw	north brabant	#ffa658
# province_raw	nairobi	#ffa055
# province_raw	yunnan	#ff9b52
# province_raw	khánh hoà province	#ff954e
# province_raw	lâm đồng province	#ff8f4b
# province_raw	ho chi minh city	#ff8947
# province_raw	guangxi zhuang	#ff8344
# province_raw	california	#ff7c40
# province_raw	la libertad	#ff763d
# province_raw	tamil nadu	#ff7039
# province_raw	saskatchewan	#ff6936
# province_raw	arizona	#ff6232
# province_raw	new mexico	#ff5c2f
# province_raw	colorado	#ff552b
# province_raw	texas	#ff4e28
# province_raw	nevada	#ff4724
# province_raw	central java	#ff4020
# province_raw	province de fianarantsoa	#ff391d
# province_raw	kirov oblast	#ff3219
# province_raw	gujarat	#ff2b16
# province_raw	fujian	#ff2412
# province_raw	midlands	#ff1d0e
# province_raw	msila	#ff160b
# province_raw	state of mato grosso	#ff0e07
# province_raw	la paz	#ff0704
# province_raw	cajamarca	#ff0000
# continent	europe	#8000ff
# continent	asia	#00b4ec
# continent	africa	#80ffb4
# continent	north america	#ffb462
# continent	south america	#ff0000
# continent_raw	europe	#8000ff
# continent_raw	asia	#00b4ec
# continent_raw	africa	#80ffb4
# continent_raw	north america	#ffb462
# continent_raw	south america	#ff0000
# host_order	human	#d62728
# host_order	rodentia	#525252
# host_order	siphonaptera	#2ca02c
# host_order	na	#FFFFFF
# host_order	lagomorpha	#1f77b4
# host_order	phthiraptera	#2ca02c
# host_order	ixodida	#2ca02c
# host_order	carnivora	#1f77b4
# host_order	artiodactyla	#1f77b4
# host_order	lepidoptera	#2ca02c
# host_order	marsupialia	#1f77b4
# host_order_raw	human	#d62728
# host_order_raw	rodentia	#525252
# host_order_raw	siphonaptera	#2ca02c
# host_order_raw	na	#FFFFFF
# host_order_raw	lagomorpha	#1f77b4
# host_order_raw	phthiraptera	#2ca02c
# host_order_raw	ixodida	#2ca02c
# host_order_raw	carnivora	#1f77b4
# host_order_raw	artiodactyla	#1f77b4
# host_order_raw	lepidoptera	#2ca02c
# host_order_raw	marsupialia	#1f77b4

# %% [markdown]
# ## Parse Tree Into Dataframe

# %%
x_posns = get_x_positions(divtree)
y_posns = get_y_positions(divtree)

# Initialize 
# Date lower and upper error bars for tips
metadata_df["date_lower"] = [NO_DATA_CHAR] * len(metadata_df)
metadata_df["date_upper"] = [NO_DATA_CHAR] * len(metadata_df)
    
for c in divtree.find_clades():
    # ------------------------------------------------------------
    # Coordinates for the divergence tree
    coord_x = [value for key,value in x_posns.items() if key.name == c.name][0]
    coord_y = [value for key,value in y_posns.items() if key.name == c.name][0]
    metadata_df.at[c.name, 'divtree_coord_x'] = coord_x
    metadata_df.at[c.name, 'divtree_coord_y'] = coord_y
    
    # ------------------------------------------------------------
    # Root to tip distance (same as div x)
    metadata_df.at[c.name, "rtt_dist"] = coord_x 

    # ------------------------------------------------------------
    # Date lower and upper error bars for tips
    date_mean = metadata_df["date_mean"][c.name] 
    if date_mean != NO_DATA_CHAR:
        metadata_df.at[c.name, "date_lower"] = date_mean - metadata_df["date_err"][c.name]
        metadata_df.at[c.name, "date_upper"] = date_mean + metadata_df["date_err"][c.name]

x_posns = get_x_positions(timetree)
y_posns = get_y_positions(timetree)


for c in timetree.find_clades():

    coord_x = [value for key,value in x_posns.items() if key.name == c.name][0]
    coord_y = [value for key,value in y_posns.items() if key.name == c.name][0]
    metadata_df.at[c.name, 'timetree_coord_x'] = coord_x
    metadata_df.at[c.name, 'timetree_coord_y'] = coord_y
    
    timetree_date = int(float(metadata_df["timetree_date"][c.name]))
    timetree_date_calendar = CURRENT_YEAR + timetree_date
    metadata_df.at[c.name, 'timetree_date_calendar'] = timetree_date_calendar
    
    timetree_CI_date = metadata_df["timetree_CI_date"][c.name]
    if timetree_CI_date == NO_DATA_CHAR:
        timetree_CI_lower_err = 0
        timetree_CI_upper_err = 0
    else:
        timetree_CI_split = [int(float(d)) for d in timetree_CI_date.strip("{}").split(",")]
        timetree_CI_calendar = [CURRENT_YEAR + d for d in timetree_CI_split]
        timetree_CI_lower_err = timetree_date_calendar - timetree_CI_calendar[0]
        timetree_CI_upper_err = timetree_CI_calendar[1] - timetree_date_calendar
    metadata_df.at[c.name,"timetree_CI_lower_err"] = timetree_CI_lower_err
    metadata_df.at[c.name,"timetree_CI_upper_err"] = timetree_CI_upper_err   

display(metadata_df)
# Out:
#                                     strain    date date_bp  \
# sample
# Reference                             CO92    1992     -29
# GCA_009909635.1_ASM990963v1_genomic   9_10  1923.0     -98
# GCA_009669545.1_ASM966954v1_genomic  42126  2006.0     -15
# GCA_009669555.1_ASM966955v1_genomic  42123  2005.0     -16
# GCA_009669565.1_ASM966956v1_genomic  42118  2005.0     -16
# ...                                    ...     ...     ...
# NODE595                                 NA      NA      NA
# NODE596                                 NA      NA      NA
# NODE597                                 NA      NA      NA
# NODE598                                 NA      NA      NA
# NODE599                                 NA      NA      NA
#
#                                                       country       province  \
# sample
# Reference                            United States of America       Colorado
# GCA_009909635.1_ASM990963v1_genomic                    Russia  Rostov Oblast
# GCA_009669545.1_ASM966954v1_genomic                     China       Xinjiang
# GCA_009669555.1_ASM966955v1_genomic                     China       Xinjiang
# GCA_009669565.1_ASM966956v1_genomic                     China       Xinjiang
# ...                                                       ...            ...
# NODE595                                                    NA             NA
# NODE596                                                    NA             NA
# NODE597                                                    NA             NA
# NODE598                                                    NA             NA
# NODE599                                                    NA             NA
#
#                                     country_lat country_lon province_lat  \
# sample
# Reference                               39.7837    -100.446      38.7252
# GCA_009909635.1_ASM990963v1_genomic     64.6863     97.7453      47.6222
# GCA_009669545.1_ASM966954v1_genomic     35.0001         105      42.4805
# GCA_009669555.1_ASM966955v1_genomic     35.0001         105      42.4805
# GCA_009669565.1_ASM966956v1_genomic     35.0001         105      42.4805
# ...                                         ...         ...          ...
# NODE595                                      NA          NA           NA
# NODE596                                      NA          NA           NA
# NODE597                                      NA          NA           NA
# NODE598                                      NA          NA           NA
# NODE599                                      NA          NA           NA
#
#                                     province_lon      biovar branch_major  \
# sample
# Reference                               -105.608  Orientalis        1.ORI
# GCA_009909635.1_ASM990963v1_genomic      40.7958  Medievalis        2.MED
# GCA_009669545.1_ASM966954v1_genomic      85.4633     Antiqua        0.ANT
# GCA_009669555.1_ASM966955v1_genomic      85.4633     Antiqua        0.ANT
# GCA_009669565.1_ASM966956v1_genomic      85.4633     Antiqua        0.ANT
# ...                                          ...         ...          ...
# NODE595                                       NA          NA           NA
# NODE596                                       NA          NA           NA
# NODE597                                       NA          NA           NA
# NODE598                                       NA          NA           NA
# NODE599                                       NA          NA           NA
#
#                                     branch_minor biosample_accession  \
# sample
# Reference                                 1.ORI1        SAMEA1705942
# GCA_009909635.1_ASM990963v1_genomic       2.MED1        SAMN13632815
# GCA_009669545.1_ASM966954v1_genomic       0.ANT1        SAMN07722925
# GCA_009669555.1_ASM966955v1_genomic       0.ANT1        SAMN07722924
# GCA_009669565.1_ASM966956v1_genomic       0.ANT1        SAMN07722923
# ...                                          ...                 ...
# NODE595                                       NA                  NA
# NODE596                                       NA                  NA
# NODE597                                       NA                  NA
# NODE598                                       NA                  NA
# NODE599                                       NA                  NA
#
#                                                    biosample_comment  \
# sample
# Reference                            KEEP: Assembly Modern Reference
# GCA_009909635.1_ASM990963v1_genomic            KEEP: Assembly Modern
# GCA_009669545.1_ASM966954v1_genomic            KEEP: Assembly Modern
# GCA_009669555.1_ASM966955v1_genomic            KEEP: Assembly Modern
# GCA_009669565.1_ASM966956v1_genomic            KEEP: Assembly Modern
# ...                                                              ...
# NODE595                                                           NA
# NODE596                                                           NA
# NODE597                                                           NA
# NODE598                                                           NA
# NODE599                                                           NA
#
#                                     branch_number      continent date_mean  \
# sample
# Reference                                       1  North America      1992
# GCA_009909635.1_ASM990963v1_genomic             2         Europe      1923
# GCA_009669545.1_ASM966954v1_genomic             0           Asia      2006
# GCA_009669555.1_ASM966955v1_genomic             0           Asia      2005
# GCA_009669565.1_ASM966956v1_genomic             0           Asia      2005
# ...                                           ...            ...       ...
# NODE595                                        NA             NA        NA
# NODE596                                        NA             NA        NA
# NODE597                                        NA             NA        NA
# NODE598                                        NA             NA        NA
# NODE599                                        NA             NA        NA
#
#                                     date_bp_mean date_err      lat      lon  \
# sample
# Reference                                     29        0  38.7252 -105.608
# GCA_009909635.1_ASM990963v1_genomic           98        0  47.6222  40.7958
# GCA_009669545.1_ASM966954v1_genomic           15        0  42.4805  85.4633
# GCA_009669555.1_ASM966955v1_genomic           16        0  42.4805  85.4633
# GCA_009669565.1_ASM966956v1_genomic           16        0  42.4805  85.4633
# ...                                          ...      ...      ...      ...
# NODE595                                       NA       NA       NA       NA
# NODE596                                       NA       NA       NA       NA
# NODE597                                       NA       NA       NA       NA
# NODE598                                       NA       NA       NA       NA
# NODE599                                       NA       NA       NA       NA
#
#                                     host_human sequencing_technology  \
# sample
# Reference                                Human                    NA
# GCA_009909635.1_ASM990963v1_genomic      Human            IonTorrent
# GCA_009669545.1_ASM966954v1_genomic  Non-Human   Illumina Hiseq 2000
# GCA_009669555.1_ASM966955v1_genomic  Non-Human   Illumina Hiseq 2000
# GCA_009669565.1_ASM966956v1_genomic  Non-Human   Illumina Hiseq 2000
# ...                                        ...                   ...
# NODE595                                     NA                    NA
# NODE596                                     NA                    NA
# NODE597                                     NA                    NA
# NODE598                                     NA                    NA
# NODE599                                     NA                    NA
#
#                                         assembly_method  \
# sample
# Reference                                            NA
# GCA_009909635.1_ASM990963v1_genomic      Newbler v. 2.6
# GCA_009669545.1_ASM966954v1_genomic  SOAPdenovo v. 2.04
# GCA_009669555.1_ASM966955v1_genomic  SOAPdenovo v. 2.04
# GCA_009669565.1_ASM966956v1_genomic  SOAPdenovo v. 2.04
# ...                                                 ...
# NODE595                                              NA
# NODE596                                              NA
# NODE597                                              NA
# NODE598                                              NA
# NODE599                                              NA
#
#                                                    host_raw    host_order  \
# sample
# Reference                                             Human         Human
# GCA_009909635.1_ASM990963v1_genomic            Homo sapiens         Human
# GCA_009669545.1_ASM966954v1_genomic      Citellus undulatus      Rodentia
# GCA_009669555.1_ASM966955v1_genomic  Frontopsylla elatoides  Siphonaptera
# GCA_009669565.1_ASM966956v1_genomic      Citellus undulatus      Rodentia
# ...                                                     ...           ...
# NODE595                                                  NA            NA
# NODE596                                                  NA            NA
# NODE597                                                  NA            NA
# NODE598                                                  NA            NA
# NODE599                                                  NA            NA
#
#                                     population_color population  \
# sample
# Reference                                    #ff0000      1.ORI
# GCA_009909635.1_ASM990963v1_genomic          #c5e88a      2.MED
# GCA_009669545.1_ASM966954v1_genomic          #238af5      0.ANT
# GCA_009669555.1_ASM966955v1_genomic          #238af5      0.ANT
# GCA_009669565.1_ASM966956v1_genomic          #238af5      0.ANT
# ...                                              ...        ...
# NODE595                                           NA         NA
# NODE596                                           NA         NA
# NODE597                                           NA         NA
# NODE598                                           NA         NA
# NODE599                                           NA         NA
#
#                                                                  geometry  \
# sample
# Reference                                  POINT (-105.607716 38.7251776)
# GCA_009909635.1_ASM990963v1_genomic         POINT (40.7957942 47.6222451)
# GCA_009669545.1_ASM966954v1_genomic  POINT (85.46334640000001 42.4804953)
# GCA_009669555.1_ASM966955v1_genomic  POINT (85.46334640000001 42.4804953)
# GCA_009669565.1_ASM966956v1_genomic  POINT (85.46334640000001 42.4804953)
# ...                                                                   ...
# NODE595                                                                NA
# NODE596                                                                NA
# NODE597                                                                NA
# NODE598                                                                NA
# NODE599                                                                NA
#
#                                     root_rtt_dist clade_rtt_dist  \
# sample
# Reference                             7.31686e-05             NA
# GCA_009909635.1_ASM990963v1_genomic   7.30501e-05             NA
# GCA_009669545.1_ASM966954v1_genomic   5.41847e-05             NA
# GCA_009669555.1_ASM966955v1_genomic   5.47035e-05             NA
# GCA_009669565.1_ASM966956v1_genomic    5.4939e-05             NA
# ...                                           ...            ...
# NODE595                                        NA             NA
# NODE596                                        NA             NA
# NODE597                                        NA             NA
# NODE598                                        NA             NA
# NODE599                                        NA             NA
#
#                                     population_rtt_dist   tstv cds_sites  \
# sample
# Reference                                    6.3815e-06     NA        NA
# GCA_009909635.1_ASM990963v1_genomic          9.6582e-06  1.854       216
# GCA_009669545.1_ASM966954v1_genomic         1.15566e-05  1.935       246
# GCA_009669555.1_ASM966955v1_genomic         1.20754e-05  2.119       241
# GCA_009669565.1_ASM966956v1_genomic         1.23109e-05      2       247
# ...                                                 ...    ...       ...
# NODE595                                              NA     NA        NA
# NODE596                                              NA     NA        NA
# NODE597                                              NA     NA        NA
# NODE598                                              NA     NA        NA
# NODE599                                              NA     NA        NA
#
#                                     ns_sites ss_sites ns_ss_ratio other_var  \
# sample
# Reference                                 NA       NA          NA        NA
# GCA_009909635.1_ASM990963v1_genomic      121       51     2.37255         1
# GCA_009669545.1_ASM966954v1_genomic      134       60     2.23333         0
# GCA_009669555.1_ASM966955v1_genomic      133       58      2.2931         0
# GCA_009669565.1_ASM966956v1_genomic      135       60        2.25         0
# ...                                      ...      ...         ...       ...
# NODE595                                   NA       NA          NA        NA
# NODE596                                   NA       NA          NA        NA
# NODE597                                   NA       NA          NA        NA
# NODE598                                   NA       NA          NA        NA
# NODE599                                   NA       NA          NA        NA
#
#                                     other_var_ratio homo_het_sites homo_sites  \
# sample
# Reference                                        NA             NA         NA
# GCA_009909635.1_ASM990963v1_genomic       0.0196078            242        216
# GCA_009669545.1_ASM966954v1_genomic               0            271        246
# GCA_009669555.1_ASM966955v1_genomic               0            258        241
# GCA_009669565.1_ASM966956v1_genomic               0            265        247
# ...                                             ...            ...        ...
# NODE595                                          NA             NA         NA
# NODE596                                          NA             NA         NA
# NODE597                                          NA             NA         NA
# NODE598                                          NA             NA         NA
# NODE599                                          NA             NA         NA
#
#                                     het_sites  het_ratio  \
# sample
# Reference                                  NA         NA
# GCA_009909635.1_ASM990963v1_genomic        26   0.107438
# GCA_009669545.1_ASM966954v1_genomic        25  0.0922509
# GCA_009669555.1_ASM966955v1_genomic        17  0.0658915
# GCA_009669565.1_ASM966956v1_genomic        18  0.0679245
# ...                                       ...        ...
# NODE595                                    NA         NA
# NODE596                                    NA         NA
# NODE597                                    NA         NA
# NODE598                                    NA         NA
# NODE599                                    NA         NA
#
#                                     external_branch_length variant_qc  \
# sample
# Reference                                       4.0046e-06       pass
# GCA_009909635.1_ASM990963v1_genomic             2.1201e-06       pass
# GCA_009669545.1_ASM966954v1_genomic                      0       pass
# GCA_009669555.1_ASM966955v1_genomic              2.356e-07       pass
# GCA_009669565.1_ASM966956v1_genomic              4.711e-07       pass
# ...                                                    ...        ...
# NODE595                                                 NA         NA
# NODE596                                                 NA         NA
# NODE597                                                 NA         NA
# NODE598                                                 NA         NA
# NODE599                                                 NA         NA
#
#                                     tstv_outlier node_type  branch_length  \
# sample
# Reference                                      0  terminal   4.004600e-06
# GCA_009909635.1_ASM990963v1_genomic            0  terminal   2.120100e-06
# GCA_009669545.1_ASM966954v1_genomic            0  terminal   0.000000e+00
# GCA_009669555.1_ASM966955v1_genomic            0  terminal   2.356000e-07
# GCA_009669565.1_ASM966956v1_genomic            0  terminal   4.711000e-07
# ...                                          ...       ...            ...
# NODE595                                       NA  internal   2.207000e-07
# NODE596                                       NA  internal   2.356000e-07
# NODE597                                       NA  internal   2.921000e-07
# NODE598                                       NA  internal   5.010000e-08
# NODE599                                       NA  internal   2.248000e-07
#
#                                      branch_support branch_support_conf_char  \
# sample
# Reference                                       0.0
# GCA_009909635.1_ASM990963v1_genomic             0.0
# GCA_009669545.1_ASM966954v1_genomic             0.0
# GCA_009669555.1_ASM966955v1_genomic             0.0
# GCA_009669565.1_ASM966956v1_genomic             0.0
# ...                                             ...                      ...
# NODE595                                        13.0
# NODE596                                        13.0
# NODE597                                        46.0
# NODE598                                        34.0
# NODE599                                        58.0
#
#                                     branch_support_conf_category  \
# sample
# Reference                                                    LOW
# GCA_009909635.1_ASM990963v1_genomic                          LOW
# GCA_009669545.1_ASM966954v1_genomic                          LOW
# GCA_009669555.1_ASM966955v1_genomic                          LOW
# GCA_009669565.1_ASM966956v1_genomic                          LOW
# ...                                                          ...
# NODE595                                                      LOW
# NODE596                                                      LOW
# NODE597                                                      LOW
# NODE598                                                      LOW
# NODE599                                                      LOW
#
#                                     timetree_date timetree_CI_height  \
# sample
# Reference                                     -29                 NA
# GCA_009909635.1_ASM990963v1_genomic           -98                 NA
# GCA_009669545.1_ASM966954v1_genomic           -15                 NA
# GCA_009669555.1_ASM966955v1_genomic           -16                 NA
# GCA_009669565.1_ASM966956v1_genomic           -16                 NA
# ...                                           ...                ...
# NODE595                                  -111.576  {89.1935,137.589}
# NODE596                                  -111.576  {89.1935,137.589}
# NODE597                                  -78.3728  {50.8548,116.815}
# NODE598                                   -70.382     {40.845,106.6}
# NODE599                                  -54.3879   {27.1416,88.513}
#
#                                         timetree_CI_date  \
# sample
# Reference                                             NA
# GCA_009909635.1_ASM990963v1_genomic                   NA
# GCA_009669545.1_ASM966954v1_genomic                   NA
# GCA_009669555.1_ASM966955v1_genomic                   NA
# GCA_009669565.1_ASM966956v1_genomic                   NA
# ...                                                  ...
# NODE595                              {-137.589,-89.1935}
# NODE596                              {-137.589,-89.1935}
# NODE597                              {-116.815,-50.8548}
# NODE598                                 {-106.6,-40.845}
# NODE599                               {-88.513,-27.1416}
#
#                                             mugration_country  \
# sample
# Reference                            United States of America
# GCA_009909635.1_ASM990963v1_genomic                    Russia
# GCA_009669545.1_ASM966954v1_genomic                     China
# GCA_009669555.1_ASM966955v1_genomic                     China
# GCA_009669565.1_ASM966956v1_genomic                     China
# ...                                                       ...
# NODE595                                                  Peru
# NODE596                                                  Peru
# NODE597                                                  Peru
# NODE598                                                  Peru
# NODE599                                                  Peru
#
#                                     mugration_province mugration_continent  \
# sample
# Reference                                     Colorado       North America
# GCA_009909635.1_ASM990963v1_genomic      Rostov Oblast              Europe
# GCA_009669545.1_ASM966954v1_genomic           Xinjiang                Asia
# GCA_009669555.1_ASM966955v1_genomic           Xinjiang                Asia
# GCA_009669565.1_ASM966956v1_genomic           Xinjiang                Asia
# ...                                                ...                 ...
# NODE595                                      Cajamarca       South America
# NODE596                                      Cajamarca       South America
# NODE597                                      Cajamarca       South America
# NODE598                                      Cajamarca       South America
# NODE599                                      Cajamarca       South America
#
#                                     mugration_host_order mugration_population  \
# sample
# Reference                                          Human                1.ORI
# GCA_009909635.1_ASM990963v1_genomic                Human                2.MED
# GCA_009669545.1_ASM966954v1_genomic             Rodentia                0.ANT
# GCA_009669555.1_ASM966955v1_genomic         Siphonaptera                0.ANT
# GCA_009669565.1_ASM966956v1_genomic             Rodentia                0.ANT
# ...                                                  ...                  ...
# NODE595                                            Human                1.ORI
# NODE596                                         Rodentia                1.ORI
# NODE597                                         Rodentia                1.ORI
# NODE598                                            Human                1.ORI
# NODE599                                         Rodentia                1.ORI
#
#                                      mugration_country_confidence  \
# sample
# Reference                                                     1.0
# GCA_009909635.1_ASM990963v1_genomic                           1.0
# GCA_009669545.1_ASM966954v1_genomic                           1.0
# GCA_009669555.1_ASM966955v1_genomic                           1.0
# GCA_009669565.1_ASM966956v1_genomic                           1.0
# ...                                                           ...
# NODE595                                                       1.0
# NODE596                                                       1.0
# NODE597                                                       1.0
# NODE598                                                       1.0
# NODE599                                                       1.0
#
#                                      mugration_country_lat_confidence  \
# sample
# Reference                                                    1.000000
# GCA_009909635.1_ASM990963v1_genomic                          1.000000
# GCA_009669545.1_ASM966954v1_genomic                          1.000000
# GCA_009669555.1_ASM966955v1_genomic                          1.000000
# GCA_009669565.1_ASM966956v1_genomic                          1.000000
# ...                                                               ...
# NODE595                                                      0.999999
# NODE596                                                      0.999999
# NODE597                                                      0.999999
# NODE598                                                      0.999999
# NODE599                                                      0.999999
#
#                                      mugration_country_lon_confidence  \
# sample
# Reference                                                    1.000000
# GCA_009909635.1_ASM990963v1_genomic                          1.000000
# GCA_009669545.1_ASM966954v1_genomic                          1.000000
# GCA_009669555.1_ASM966955v1_genomic                          1.000000
# GCA_009669565.1_ASM966956v1_genomic                          1.000000
# ...                                                               ...
# NODE595                                                      0.999999
# NODE596                                                      0.999999
# NODE597                                                      0.999999
# NODE598                                                      0.999999
# NODE599                                                      0.999999
#
#                                      mugration_province_confidence  \
# sample
# Reference                                                     1.00
# GCA_009909635.1_ASM990963v1_genomic                           1.00
# GCA_009669545.1_ASM966954v1_genomic                           1.00
# GCA_009669555.1_ASM966955v1_genomic                           1.00
# GCA_009669565.1_ASM966956v1_genomic                           1.00
# ...                                                            ...
# NODE595                                                       1.00
# NODE596                                                       1.00
# NODE597                                                       1.00
# NODE598                                                       1.00
# NODE599                                                       0.99
#
#                                      mugration_province_lat_confidence  \
# sample
# Reference                                                     1.000000
# GCA_009909635.1_ASM990963v1_genomic                           1.000000
# GCA_009669545.1_ASM966954v1_genomic                           1.000000
# GCA_009669555.1_ASM966955v1_genomic                           1.000000
# GCA_009669565.1_ASM966956v1_genomic                           1.000000
# ...                                                                ...
# NODE595                                                       0.999873
# NODE596                                                       0.999998
# NODE597                                                       0.999999
# NODE598                                                       0.999874
# NODE599                                                       0.991635
#
#                                      mugration_province_lon_confidence  \
# sample
# Reference                                                     1.000000
# GCA_009909635.1_ASM990963v1_genomic                           1.000000
# GCA_009669545.1_ASM966954v1_genomic                           1.000000
# GCA_009669555.1_ASM966955v1_genomic                           1.000000
# GCA_009669565.1_ASM966956v1_genomic                           1.000000
# ...                                                                ...
# NODE595                                                       0.999873
# NODE596                                                       0.999998
# NODE597                                                       0.999999
# NODE598                                                       0.999874
# NODE599                                                       0.991635
#
#                                      mugration_continent_confidence  \
# sample
# Reference                                                       1.0
# GCA_009909635.1_ASM990963v1_genomic                             1.0
# GCA_009669545.1_ASM966954v1_genomic                             1.0
# GCA_009669555.1_ASM966955v1_genomic                             1.0
# GCA_009669565.1_ASM966956v1_genomic                             1.0
# ...                                                             ...
# NODE595                                                         1.0
# NODE596                                                         1.0
# NODE597                                                         1.0
# NODE598                                                         1.0
# NODE599                                                         1.0
#
#                                      mugration_host_order_confidence  \
# sample
# Reference                                                       1.00
# GCA_009909635.1_ASM990963v1_genomic                             1.00
# GCA_009669545.1_ASM966954v1_genomic                             1.00
# GCA_009669555.1_ASM966955v1_genomic                             1.00
# GCA_009669565.1_ASM966956v1_genomic                             1.00
# ...                                                              ...
# NODE595                                                         0.55
# NODE596                                                         0.61
# NODE597                                                         0.56
# NODE598                                                         0.60
# NODE599                                                         0.82
#
#                                      mugration_population_confidence  \
# sample
# Reference                                                        1.0
# GCA_009909635.1_ASM990963v1_genomic                              1.0
# GCA_009669545.1_ASM966954v1_genomic                              1.0
# GCA_009669555.1_ASM966955v1_genomic                              1.0
# GCA_009669565.1_ASM966956v1_genomic                              1.0
# ...                                                              ...
# NODE595                                                          1.0
# NODE596                                                          1.0
# NODE597                                                          1.0
# NODE598                                                          1.0
# NODE599                                                          1.0
#
#                                      mugration_country_lat  \
# sample
# Reference                                        39.783730
# GCA_009909635.1_ASM990963v1_genomic              64.686314
# GCA_009669545.1_ASM966954v1_genomic              35.000074
# GCA_009669555.1_ASM966955v1_genomic              35.000074
# GCA_009669565.1_ASM966956v1_genomic              35.000074
# ...                                                    ...
# NODE595                                          -6.869970
# NODE596                                          -6.869970
# NODE597                                          -6.869970
# NODE598                                          -6.869970
# NODE599                                          -6.869970
#
#                                      mugration_country_lon  \
# sample
# Reference                                      -100.445882
# GCA_009909635.1_ASM990963v1_genomic              97.745306
# GCA_009669545.1_ASM966954v1_genomic             104.999927
# GCA_009669555.1_ASM966955v1_genomic             104.999927
# GCA_009669565.1_ASM966956v1_genomic             104.999927
# ...                                                    ...
# NODE595                                         -75.045851
# NODE596                                         -75.045851
# NODE597                                         -75.045851
# NODE598                                         -75.045851
# NODE599                                         -75.045851
#
#                                      mugration_province_lat  \
# sample
# Reference                                         38.725178
# GCA_009909635.1_ASM990963v1_genomic               47.622245
# GCA_009669545.1_ASM966954v1_genomic               42.480495
# GCA_009669555.1_ASM966955v1_genomic               42.480495
# GCA_009669565.1_ASM966956v1_genomic               42.480495
# ...                                                     ...
# NODE595                                           -6.250000
# NODE596                                           -6.250000
# NODE597                                           -6.250000
# NODE598                                           -6.250000
# NODE599                                           -6.250000
#
#                                      mugration_province_lon  \
# sample
# Reference                                       -105.607716
# GCA_009909635.1_ASM990963v1_genomic               40.795794
# GCA_009669545.1_ASM966954v1_genomic               85.463346
# GCA_009669555.1_ASM966955v1_genomic               85.463346
# GCA_009669565.1_ASM966956v1_genomic               85.463346
# ...                                                     ...
# NODE595                                          -78.833333
# NODE596                                          -78.833333
# NODE597                                          -78.833333
# NODE598                                          -78.833333
# NODE599                                          -78.833333
#
#                                      branch_length_sub  branch_length_time  \
# sample
# Reference                                    16.935846           162.52800
# GCA_009909635.1_ASM990963v1_genomic           8.966111           878.89200
# GCA_009669545.1_ASM966954v1_genomic           0.000000             9.23246
# GCA_009669555.1_ASM966955v1_genomic           0.996375            24.38400
# GCA_009669565.1_ASM966956v1_genomic           1.992328            35.90130
# ...                                                ...                 ...
# NODE595                                       0.933362             0.00000
# NODE596                                       0.996375             0.00000
# NODE597                                       1.235320            33.20350
# NODE598                                       0.211878            41.19420
# NODE599                                       0.950701            15.99410
#
#                                          rate_sub  rate_sub_year date_lower  \
# sample
# Reference                            2.463945e-08       0.104203       1992
# GCA_009909635.1_ASM990963v1_genomic  2.412242e-09       0.010202       1923
# GCA_009669545.1_ASM966954v1_genomic  0.000000e+00       0.000000       2006
# GCA_009669555.1_ASM966955v1_genomic  9.662073e-09       0.040862       2005
# GCA_009669565.1_ASM966956v1_genomic  1.312209e-08       0.055495       2005
# ...                                           ...            ...        ...
# NODE595                              0.000000e+00       0.000000         NA
# NODE596                              0.000000e+00       0.000000         NA
# NODE597                              8.797265e-09       0.037204         NA
# NODE598                              1.216191e-09       0.005143         NA
# NODE599                              1.405518e-08       0.059441         NA
#
#                                     date_upper  divtree_coord_x  \
# sample
# Reference                                 1992         0.000073
# GCA_009909635.1_ASM990963v1_genomic       1923         0.000073
# GCA_009669545.1_ASM966954v1_genomic       2006         0.000054
# GCA_009669555.1_ASM966955v1_genomic       2005         0.000055
# GCA_009669565.1_ASM966956v1_genomic       2005         0.000055
# ...                                        ...              ...
# NODE595                                     NA         0.000072
# NODE596                                     NA         0.000072
# NODE597                                     NA         0.000073
# NODE598                                     NA         0.000072
# NODE599                                     NA         0.000072
#
#                                      divtree_coord_y  rtt_dist  \
# sample
# Reference                                     509.00  0.000073
# GCA_009909635.1_ASM990963v1_genomic           339.00  0.000073
# GCA_009669545.1_ASM966954v1_genomic           152.00  0.000054
# GCA_009669555.1_ASM966955v1_genomic           171.00  0.000055
# GCA_009669565.1_ASM966956v1_genomic           173.00  0.000055
# ...                                              ...       ...
# NODE595                                       598.25  0.000072
# NODE596                                       596.75  0.000072
# NODE597                                       597.50  0.000073
# NODE598                                       599.75  0.000072
# NODE599                                       600.50  0.000072
#
#                                      timetree_coord_x  timetree_coord_y  \
# sample
# Reference                                 5249.006080            509.00
# GCA_009909635.1_ASM990963v1_genomic       5180.006106            339.00
# GCA_009669545.1_ASM966954v1_genomic       5263.005722            152.00
# GCA_009669555.1_ASM966955v1_genomic       5262.005752            171.00
# GCA_009669565.1_ASM966956v1_genomic       5262.005752            173.00
# ...                                               ...               ...
# NODE595                                   5166.429640            598.25
# NODE596                                   5166.429640            596.75
# NODE597                                   5199.633140            597.50
# NODE598                                   5207.623840            599.75
# NODE599                                   5223.617940            600.50
#
#                                      timetree_date_calendar  \
# sample
# Reference                                            1992.0
# GCA_009909635.1_ASM990963v1_genomic                  1923.0
# GCA_009669545.1_ASM966954v1_genomic                  2006.0
# GCA_009669555.1_ASM966955v1_genomic                  2005.0
# GCA_009669565.1_ASM966956v1_genomic                  2005.0
# ...                                                     ...
# NODE595                                              1910.0
# NODE596                                              1910.0
# NODE597                                              1943.0
# NODE598                                              1951.0
# NODE599                                              1967.0
#
#                                      timetree_CI_lower_err  \
# sample
# Reference                                              0.0
# GCA_009909635.1_ASM990963v1_genomic                    0.0
# GCA_009669545.1_ASM966954v1_genomic                    0.0
# GCA_009669555.1_ASM966955v1_genomic                    0.0
# GCA_009669565.1_ASM966956v1_genomic                    0.0
# ...                                                    ...
# NODE595                                               26.0
# NODE596                                               26.0
# NODE597                                               38.0
# NODE598                                               36.0
# NODE599                                               34.0
#
#                                      timetree_CI_upper_err
# sample
# Reference                                              0.0
# GCA_009909635.1_ASM990963v1_genomic                    0.0
# GCA_009669545.1_ASM966954v1_genomic                    0.0
# GCA_009669555.1_ASM966955v1_genomic                    0.0
# GCA_009669565.1_ASM966956v1_genomic                    0.0
# ...                                                    ...
# NODE595                                               22.0
# NODE596                                               22.0
# NODE597                                               28.0
# NODE598                                               30.0
# NODE599                                               27.0
#
# [1201 rows x 86 columns]

# %% [markdown]
# ## Create Custom Columns

# %%
for c in divtree.get_terminals():
    strain = metadata_df["strain"][c.name]
    country = metadata_df["country"][c.name]
    province = metadata_df["country"][c.name]
    date = metadata_df["date"][c.name]
    if type(date) == str:
        date = date.strip("[]")
    metadata_df.at[c.name,"country_date_strain"] = "{} ({}) {}".format(country, date, strain)
    metadata_df.at[c.name,"province_date_strain"] = "{} ({}) {}".format(province, date, strain)
    
metadata_df.fillna(NO_DATA_CHAR, inplace=True)

# %% [markdown]
# ## Dist To Root

# %%
lat = metadata_df["mugration_province_lat"]["NODE0"]
lon = metadata_df["mugration_province_lon"]["NODE0"]
root_coord = (lat, lon) 
geo_attr = "country"

# Root Dist
for rec in metadata_df.iterrows():
    sample = rec[0]
    lon = metadata_df["mugration_{}_lon".format(geo_attr)][sample]
    lat = metadata_df["mugration_{}_lat".format(geo_attr)][sample]
    sample_coord = (lat, lon)
    geo_dist = round(geopy.distance.great_circle(root_coord, sample_coord).km, 8)
    metadata_df.at[sample, "root_geo_dist"] = geo_dist

# Population Dist
for population in population_list:
    print(population)
    df = metadata_df[metadata_df["mugration_population"] == population]
    tips = list(df.index)
    mrca = divtree.common_ancestor(tips)
    mugration_conf = metadata_df["mugration_{}_confidence".format(geo_attr)][mrca.name]
    print(mugration_conf)
    lat = metadata_df["mugration_{}_lat".format(geo_attr)][mrca.name]
    lon = metadata_df["mugration_{}_lon".format(geo_attr)][mrca.name]
    mrca_coord = (lat, lon)
    
    df = metadata_df[metadata_df["mugration_population"] == population]
    for sample in df.index:
        lon = metadata_df["mugration_{}_lon".format(geo_attr)][sample]
        lat = metadata_df["mugration_{}_lat".format(geo_attr)][sample]
        sample_coord = (lat, lon)
        geo_dist = round(geopy.distance.great_circle(mrca_coord, sample_coord).km, 8)
        metadata_df.at[sample, "population_geo_dist"] = geo_dist   
        
display(metadata_df)
# Out:
# 0.PRE
# 0.85
# 0.PE
# 0.71
# 0.ANT
# 0.92
# 0.ANT4
# 0.69
# 3.ANT
# 0.95
# 4.ANT
# 0.92
# 2.ANT
# 0.96
# 2.MED
# 0.94
# 1.PRE
# 0.93
# 1.ANT
# 0.41
# 1.IN
# 1.0
# 1.ORI
# 1.0
#                                     strain    date date_bp  \
# sample
# Reference                             CO92    1992     -29
# GCA_009909635.1_ASM990963v1_genomic   9_10  1923.0     -98
# GCA_009669545.1_ASM966954v1_genomic  42126  2006.0     -15
# GCA_009669555.1_ASM966955v1_genomic  42123  2005.0     -16
# GCA_009669565.1_ASM966956v1_genomic  42118  2005.0     -16
# ...                                    ...     ...     ...
# NODE595                                 NA      NA      NA
# NODE596                                 NA      NA      NA
# NODE597                                 NA      NA      NA
# NODE598                                 NA      NA      NA
# NODE599                                 NA      NA      NA
#
#                                                       country       province  \
# sample
# Reference                            United States of America       Colorado
# GCA_009909635.1_ASM990963v1_genomic                    Russia  Rostov Oblast
# GCA_009669545.1_ASM966954v1_genomic                     China       Xinjiang
# GCA_009669555.1_ASM966955v1_genomic                     China       Xinjiang
# GCA_009669565.1_ASM966956v1_genomic                     China       Xinjiang
# ...                                                       ...            ...
# NODE595                                                    NA             NA
# NODE596                                                    NA             NA
# NODE597                                                    NA             NA
# NODE598                                                    NA             NA
# NODE599                                                    NA             NA
#
#                                     country_lat country_lon province_lat  \
# sample
# Reference                               39.7837    -100.446      38.7252
# GCA_009909635.1_ASM990963v1_genomic     64.6863     97.7453      47.6222
# GCA_009669545.1_ASM966954v1_genomic     35.0001         105      42.4805
# GCA_009669555.1_ASM966955v1_genomic     35.0001         105      42.4805
# GCA_009669565.1_ASM966956v1_genomic     35.0001         105      42.4805
# ...                                         ...         ...          ...
# NODE595                                      NA          NA           NA
# NODE596                                      NA          NA           NA
# NODE597                                      NA          NA           NA
# NODE598                                      NA          NA           NA
# NODE599                                      NA          NA           NA
#
#                                     province_lon      biovar branch_major  \
# sample
# Reference                               -105.608  Orientalis        1.ORI
# GCA_009909635.1_ASM990963v1_genomic      40.7958  Medievalis        2.MED
# GCA_009669545.1_ASM966954v1_genomic      85.4633     Antiqua        0.ANT
# GCA_009669555.1_ASM966955v1_genomic      85.4633     Antiqua        0.ANT
# GCA_009669565.1_ASM966956v1_genomic      85.4633     Antiqua        0.ANT
# ...                                          ...         ...          ...
# NODE595                                       NA          NA           NA
# NODE596                                       NA          NA           NA
# NODE597                                       NA          NA           NA
# NODE598                                       NA          NA           NA
# NODE599                                       NA          NA           NA
#
#                                     branch_minor biosample_accession  \
# sample
# Reference                                 1.ORI1        SAMEA1705942
# GCA_009909635.1_ASM990963v1_genomic       2.MED1        SAMN13632815
# GCA_009669545.1_ASM966954v1_genomic       0.ANT1        SAMN07722925
# GCA_009669555.1_ASM966955v1_genomic       0.ANT1        SAMN07722924
# GCA_009669565.1_ASM966956v1_genomic       0.ANT1        SAMN07722923
# ...                                          ...                 ...
# NODE595                                       NA                  NA
# NODE596                                       NA                  NA
# NODE597                                       NA                  NA
# NODE598                                       NA                  NA
# NODE599                                       NA                  NA
#
#                                                    biosample_comment  \
# sample
# Reference                            KEEP: Assembly Modern Reference
# GCA_009909635.1_ASM990963v1_genomic            KEEP: Assembly Modern
# GCA_009669545.1_ASM966954v1_genomic            KEEP: Assembly Modern
# GCA_009669555.1_ASM966955v1_genomic            KEEP: Assembly Modern
# GCA_009669565.1_ASM966956v1_genomic            KEEP: Assembly Modern
# ...                                                              ...
# NODE595                                                           NA
# NODE596                                                           NA
# NODE597                                                           NA
# NODE598                                                           NA
# NODE599                                                           NA
#
#                                     branch_number      continent date_mean  \
# sample
# Reference                                       1  North America      1992
# GCA_009909635.1_ASM990963v1_genomic             2         Europe      1923
# GCA_009669545.1_ASM966954v1_genomic             0           Asia      2006
# GCA_009669555.1_ASM966955v1_genomic             0           Asia      2005
# GCA_009669565.1_ASM966956v1_genomic             0           Asia      2005
# ...                                           ...            ...       ...
# NODE595                                        NA             NA        NA
# NODE596                                        NA             NA        NA
# NODE597                                        NA             NA        NA
# NODE598                                        NA             NA        NA
# NODE599                                        NA             NA        NA
#
#                                     date_bp_mean date_err      lat      lon  \
# sample
# Reference                                     29        0  38.7252 -105.608
# GCA_009909635.1_ASM990963v1_genomic           98        0  47.6222  40.7958
# GCA_009669545.1_ASM966954v1_genomic           15        0  42.4805  85.4633
# GCA_009669555.1_ASM966955v1_genomic           16        0  42.4805  85.4633
# GCA_009669565.1_ASM966956v1_genomic           16        0  42.4805  85.4633
# ...                                          ...      ...      ...      ...
# NODE595                                       NA       NA       NA       NA
# NODE596                                       NA       NA       NA       NA
# NODE597                                       NA       NA       NA       NA
# NODE598                                       NA       NA       NA       NA
# NODE599                                       NA       NA       NA       NA
#
#                                     host_human sequencing_technology  \
# sample
# Reference                                Human                    NA
# GCA_009909635.1_ASM990963v1_genomic      Human            IonTorrent
# GCA_009669545.1_ASM966954v1_genomic  Non-Human   Illumina Hiseq 2000
# GCA_009669555.1_ASM966955v1_genomic  Non-Human   Illumina Hiseq 2000
# GCA_009669565.1_ASM966956v1_genomic  Non-Human   Illumina Hiseq 2000
# ...                                        ...                   ...
# NODE595                                     NA                    NA
# NODE596                                     NA                    NA
# NODE597                                     NA                    NA
# NODE598                                     NA                    NA
# NODE599                                     NA                    NA
#
#                                         assembly_method  \
# sample
# Reference                                            NA
# GCA_009909635.1_ASM990963v1_genomic      Newbler v. 2.6
# GCA_009669545.1_ASM966954v1_genomic  SOAPdenovo v. 2.04
# GCA_009669555.1_ASM966955v1_genomic  SOAPdenovo v. 2.04
# GCA_009669565.1_ASM966956v1_genomic  SOAPdenovo v. 2.04
# ...                                                 ...
# NODE595                                              NA
# NODE596                                              NA
# NODE597                                              NA
# NODE598                                              NA
# NODE599                                              NA
#
#                                                    host_raw    host_order  \
# sample
# Reference                                             Human         Human
# GCA_009909635.1_ASM990963v1_genomic            Homo sapiens         Human
# GCA_009669545.1_ASM966954v1_genomic      Citellus undulatus      Rodentia
# GCA_009669555.1_ASM966955v1_genomic  Frontopsylla elatoides  Siphonaptera
# GCA_009669565.1_ASM966956v1_genomic      Citellus undulatus      Rodentia
# ...                                                     ...           ...
# NODE595                                                  NA            NA
# NODE596                                                  NA            NA
# NODE597                                                  NA            NA
# NODE598                                                  NA            NA
# NODE599                                                  NA            NA
#
#                                     population_color population  \
# sample
# Reference                                    #ff0000      1.ORI
# GCA_009909635.1_ASM990963v1_genomic          #c5e88a      2.MED
# GCA_009669545.1_ASM966954v1_genomic          #238af5      0.ANT
# GCA_009669555.1_ASM966955v1_genomic          #238af5      0.ANT
# GCA_009669565.1_ASM966956v1_genomic          #238af5      0.ANT
# ...                                              ...        ...
# NODE595                                           NA         NA
# NODE596                                           NA         NA
# NODE597                                           NA         NA
# NODE598                                           NA         NA
# NODE599                                           NA         NA
#
#                                                                  geometry  \
# sample
# Reference                                  POINT (-105.607716 38.7251776)
# GCA_009909635.1_ASM990963v1_genomic         POINT (40.7957942 47.6222451)
# GCA_009669545.1_ASM966954v1_genomic  POINT (85.46334640000001 42.4804953)
# GCA_009669555.1_ASM966955v1_genomic  POINT (85.46334640000001 42.4804953)
# GCA_009669565.1_ASM966956v1_genomic  POINT (85.46334640000001 42.4804953)
# ...                                                                   ...
# NODE595                                                                NA
# NODE596                                                                NA
# NODE597                                                                NA
# NODE598                                                                NA
# NODE599                                                                NA
#
#                                     root_rtt_dist clade_rtt_dist  \
# sample
# Reference                             7.31686e-05             NA
# GCA_009909635.1_ASM990963v1_genomic   7.30501e-05             NA
# GCA_009669545.1_ASM966954v1_genomic   5.41847e-05             NA
# GCA_009669555.1_ASM966955v1_genomic   5.47035e-05             NA
# GCA_009669565.1_ASM966956v1_genomic    5.4939e-05             NA
# ...                                           ...            ...
# NODE595                                        NA             NA
# NODE596                                        NA             NA
# NODE597                                        NA             NA
# NODE598                                        NA             NA
# NODE599                                        NA             NA
#
#                                     population_rtt_dist   tstv cds_sites  \
# sample
# Reference                                    6.3815e-06     NA        NA
# GCA_009909635.1_ASM990963v1_genomic          9.6582e-06  1.854       216
# GCA_009669545.1_ASM966954v1_genomic         1.15566e-05  1.935       246
# GCA_009669555.1_ASM966955v1_genomic         1.20754e-05  2.119       241
# GCA_009669565.1_ASM966956v1_genomic         1.23109e-05      2       247
# ...                                                 ...    ...       ...
# NODE595                                              NA     NA        NA
# NODE596                                              NA     NA        NA
# NODE597                                              NA     NA        NA
# NODE598                                              NA     NA        NA
# NODE599                                              NA     NA        NA
#
#                                     ns_sites ss_sites ns_ss_ratio other_var  \
# sample
# Reference                                 NA       NA          NA        NA
# GCA_009909635.1_ASM990963v1_genomic      121       51     2.37255         1
# GCA_009669545.1_ASM966954v1_genomic      134       60     2.23333         0
# GCA_009669555.1_ASM966955v1_genomic      133       58      2.2931         0
# GCA_009669565.1_ASM966956v1_genomic      135       60        2.25         0
# ...                                      ...      ...         ...       ...
# NODE595                                   NA       NA          NA        NA
# NODE596                                   NA       NA          NA        NA
# NODE597                                   NA       NA          NA        NA
# NODE598                                   NA       NA          NA        NA
# NODE599                                   NA       NA          NA        NA
#
#                                     other_var_ratio homo_het_sites homo_sites  \
# sample
# Reference                                        NA             NA         NA
# GCA_009909635.1_ASM990963v1_genomic       0.0196078            242        216
# GCA_009669545.1_ASM966954v1_genomic               0            271        246
# GCA_009669555.1_ASM966955v1_genomic               0            258        241
# GCA_009669565.1_ASM966956v1_genomic               0            265        247
# ...                                             ...            ...        ...
# NODE595                                          NA             NA         NA
# NODE596                                          NA             NA         NA
# NODE597                                          NA             NA         NA
# NODE598                                          NA             NA         NA
# NODE599                                          NA             NA         NA
#
#                                     het_sites  het_ratio  \
# sample
# Reference                                  NA         NA
# GCA_009909635.1_ASM990963v1_genomic        26   0.107438
# GCA_009669545.1_ASM966954v1_genomic        25  0.0922509
# GCA_009669555.1_ASM966955v1_genomic        17  0.0658915
# GCA_009669565.1_ASM966956v1_genomic        18  0.0679245
# ...                                       ...        ...
# NODE595                                    NA         NA
# NODE596                                    NA         NA
# NODE597                                    NA         NA
# NODE598                                    NA         NA
# NODE599                                    NA         NA
#
#                                     external_branch_length variant_qc  \
# sample
# Reference                                       4.0046e-06       pass
# GCA_009909635.1_ASM990963v1_genomic             2.1201e-06       pass
# GCA_009669545.1_ASM966954v1_genomic                      0       pass
# GCA_009669555.1_ASM966955v1_genomic              2.356e-07       pass
# GCA_009669565.1_ASM966956v1_genomic              4.711e-07       pass
# ...                                                    ...        ...
# NODE595                                                 NA         NA
# NODE596                                                 NA         NA
# NODE597                                                 NA         NA
# NODE598                                                 NA         NA
# NODE599                                                 NA         NA
#
#                                     tstv_outlier node_type  branch_length  \
# sample
# Reference                                      0  terminal   4.004600e-06
# GCA_009909635.1_ASM990963v1_genomic            0  terminal   2.120100e-06
# GCA_009669545.1_ASM966954v1_genomic            0  terminal   0.000000e+00
# GCA_009669555.1_ASM966955v1_genomic            0  terminal   2.356000e-07
# GCA_009669565.1_ASM966956v1_genomic            0  terminal   4.711000e-07
# ...                                          ...       ...            ...
# NODE595                                       NA  internal   2.207000e-07
# NODE596                                       NA  internal   2.356000e-07
# NODE597                                       NA  internal   2.921000e-07
# NODE598                                       NA  internal   5.010000e-08
# NODE599                                       NA  internal   2.248000e-07
#
#                                      branch_support branch_support_conf_char  \
# sample
# Reference                                       0.0
# GCA_009909635.1_ASM990963v1_genomic             0.0
# GCA_009669545.1_ASM966954v1_genomic             0.0
# GCA_009669555.1_ASM966955v1_genomic             0.0
# GCA_009669565.1_ASM966956v1_genomic             0.0
# ...                                             ...                      ...
# NODE595                                        13.0
# NODE596                                        13.0
# NODE597                                        46.0
# NODE598                                        34.0
# NODE599                                        58.0
#
#                                     branch_support_conf_category  \
# sample
# Reference                                                    LOW
# GCA_009909635.1_ASM990963v1_genomic                          LOW
# GCA_009669545.1_ASM966954v1_genomic                          LOW
# GCA_009669555.1_ASM966955v1_genomic                          LOW
# GCA_009669565.1_ASM966956v1_genomic                          LOW
# ...                                                          ...
# NODE595                                                      LOW
# NODE596                                                      LOW
# NODE597                                                      LOW
# NODE598                                                      LOW
# NODE599                                                      LOW
#
#                                     timetree_date timetree_CI_height  \
# sample
# Reference                                     -29                 NA
# GCA_009909635.1_ASM990963v1_genomic           -98                 NA
# GCA_009669545.1_ASM966954v1_genomic           -15                 NA
# GCA_009669555.1_ASM966955v1_genomic           -16                 NA
# GCA_009669565.1_ASM966956v1_genomic           -16                 NA
# ...                                           ...                ...
# NODE595                                  -111.576  {89.1935,137.589}
# NODE596                                  -111.576  {89.1935,137.589}
# NODE597                                  -78.3728  {50.8548,116.815}
# NODE598                                   -70.382     {40.845,106.6}
# NODE599                                  -54.3879   {27.1416,88.513}
#
#                                         timetree_CI_date  \
# sample
# Reference                                             NA
# GCA_009909635.1_ASM990963v1_genomic                   NA
# GCA_009669545.1_ASM966954v1_genomic                   NA
# GCA_009669555.1_ASM966955v1_genomic                   NA
# GCA_009669565.1_ASM966956v1_genomic                   NA
# ...                                                  ...
# NODE595                              {-137.589,-89.1935}
# NODE596                              {-137.589,-89.1935}
# NODE597                              {-116.815,-50.8548}
# NODE598                                 {-106.6,-40.845}
# NODE599                               {-88.513,-27.1416}
#
#                                             mugration_country  \
# sample
# Reference                            United States of America
# GCA_009909635.1_ASM990963v1_genomic                    Russia
# GCA_009669545.1_ASM966954v1_genomic                     China
# GCA_009669555.1_ASM966955v1_genomic                     China
# GCA_009669565.1_ASM966956v1_genomic                     China
# ...                                                       ...
# NODE595                                                  Peru
# NODE596                                                  Peru
# NODE597                                                  Peru
# NODE598                                                  Peru
# NODE599                                                  Peru
#
#                                     mugration_province mugration_continent  \
# sample
# Reference                                     Colorado       North America
# GCA_009909635.1_ASM990963v1_genomic      Rostov Oblast              Europe
# GCA_009669545.1_ASM966954v1_genomic           Xinjiang                Asia
# GCA_009669555.1_ASM966955v1_genomic           Xinjiang                Asia
# GCA_009669565.1_ASM966956v1_genomic           Xinjiang                Asia
# ...                                                ...                 ...
# NODE595                                      Cajamarca       South America
# NODE596                                      Cajamarca       South America
# NODE597                                      Cajamarca       South America
# NODE598                                      Cajamarca       South America
# NODE599                                      Cajamarca       South America
#
#                                     mugration_host_order mugration_population  \
# sample
# Reference                                          Human                1.ORI
# GCA_009909635.1_ASM990963v1_genomic                Human                2.MED
# GCA_009669545.1_ASM966954v1_genomic             Rodentia                0.ANT
# GCA_009669555.1_ASM966955v1_genomic         Siphonaptera                0.ANT
# GCA_009669565.1_ASM966956v1_genomic             Rodentia                0.ANT
# ...                                                  ...                  ...
# NODE595                                            Human                1.ORI
# NODE596                                         Rodentia                1.ORI
# NODE597                                         Rodentia                1.ORI
# NODE598                                            Human                1.ORI
# NODE599                                         Rodentia                1.ORI
#
#                                      mugration_country_confidence  \
# sample
# Reference                                                     1.0
# GCA_009909635.1_ASM990963v1_genomic                           1.0
# GCA_009669545.1_ASM966954v1_genomic                           1.0
# GCA_009669555.1_ASM966955v1_genomic                           1.0
# GCA_009669565.1_ASM966956v1_genomic                           1.0
# ...                                                           ...
# NODE595                                                       1.0
# NODE596                                                       1.0
# NODE597                                                       1.0
# NODE598                                                       1.0
# NODE599                                                       1.0
#
#                                      mugration_country_lat_confidence  \
# sample
# Reference                                                    1.000000
# GCA_009909635.1_ASM990963v1_genomic                          1.000000
# GCA_009669545.1_ASM966954v1_genomic                          1.000000
# GCA_009669555.1_ASM966955v1_genomic                          1.000000
# GCA_009669565.1_ASM966956v1_genomic                          1.000000
# ...                                                               ...
# NODE595                                                      0.999999
# NODE596                                                      0.999999
# NODE597                                                      0.999999
# NODE598                                                      0.999999
# NODE599                                                      0.999999
#
#                                      mugration_country_lon_confidence  \
# sample
# Reference                                                    1.000000
# GCA_009909635.1_ASM990963v1_genomic                          1.000000
# GCA_009669545.1_ASM966954v1_genomic                          1.000000
# GCA_009669555.1_ASM966955v1_genomic                          1.000000
# GCA_009669565.1_ASM966956v1_genomic                          1.000000
# ...                                                               ...
# NODE595                                                      0.999999
# NODE596                                                      0.999999
# NODE597                                                      0.999999
# NODE598                                                      0.999999
# NODE599                                                      0.999999
#
#                                      mugration_province_confidence  \
# sample
# Reference                                                     1.00
# GCA_009909635.1_ASM990963v1_genomic                           1.00
# GCA_009669545.1_ASM966954v1_genomic                           1.00
# GCA_009669555.1_ASM966955v1_genomic                           1.00
# GCA_009669565.1_ASM966956v1_genomic                           1.00
# ...                                                            ...
# NODE595                                                       1.00
# NODE596                                                       1.00
# NODE597                                                       1.00
# NODE598                                                       1.00
# NODE599                                                       0.99
#
#                                      mugration_province_lat_confidence  \
# sample
# Reference                                                     1.000000
# GCA_009909635.1_ASM990963v1_genomic                           1.000000
# GCA_009669545.1_ASM966954v1_genomic                           1.000000
# GCA_009669555.1_ASM966955v1_genomic                           1.000000
# GCA_009669565.1_ASM966956v1_genomic                           1.000000
# ...                                                                ...
# NODE595                                                       0.999873
# NODE596                                                       0.999998
# NODE597                                                       0.999999
# NODE598                                                       0.999874
# NODE599                                                       0.991635
#
#                                      mugration_province_lon_confidence  \
# sample
# Reference                                                     1.000000
# GCA_009909635.1_ASM990963v1_genomic                           1.000000
# GCA_009669545.1_ASM966954v1_genomic                           1.000000
# GCA_009669555.1_ASM966955v1_genomic                           1.000000
# GCA_009669565.1_ASM966956v1_genomic                           1.000000
# ...                                                                ...
# NODE595                                                       0.999873
# NODE596                                                       0.999998
# NODE597                                                       0.999999
# NODE598                                                       0.999874
# NODE599                                                       0.991635
#
#                                      mugration_continent_confidence  \
# sample
# Reference                                                       1.0
# GCA_009909635.1_ASM990963v1_genomic                             1.0
# GCA_009669545.1_ASM966954v1_genomic                             1.0
# GCA_009669555.1_ASM966955v1_genomic                             1.0
# GCA_009669565.1_ASM966956v1_genomic                             1.0
# ...                                                             ...
# NODE595                                                         1.0
# NODE596                                                         1.0
# NODE597                                                         1.0
# NODE598                                                         1.0
# NODE599                                                         1.0
#
#                                      mugration_host_order_confidence  \
# sample
# Reference                                                       1.00
# GCA_009909635.1_ASM990963v1_genomic                             1.00
# GCA_009669545.1_ASM966954v1_genomic                             1.00
# GCA_009669555.1_ASM966955v1_genomic                             1.00
# GCA_009669565.1_ASM966956v1_genomic                             1.00
# ...                                                              ...
# NODE595                                                         0.55
# NODE596                                                         0.61
# NODE597                                                         0.56
# NODE598                                                         0.60
# NODE599                                                         0.82
#
#                                      mugration_population_confidence  \
# sample
# Reference                                                        1.0
# GCA_009909635.1_ASM990963v1_genomic                              1.0
# GCA_009669545.1_ASM966954v1_genomic                              1.0
# GCA_009669555.1_ASM966955v1_genomic                              1.0
# GCA_009669565.1_ASM966956v1_genomic                              1.0
# ...                                                              ...
# NODE595                                                          1.0
# NODE596                                                          1.0
# NODE597                                                          1.0
# NODE598                                                          1.0
# NODE599                                                          1.0
#
#                                      mugration_country_lat  \
# sample
# Reference                                        39.783730
# GCA_009909635.1_ASM990963v1_genomic              64.686314
# GCA_009669545.1_ASM966954v1_genomic              35.000074
# GCA_009669555.1_ASM966955v1_genomic              35.000074
# GCA_009669565.1_ASM966956v1_genomic              35.000074
# ...                                                    ...
# NODE595                                          -6.869970
# NODE596                                          -6.869970
# NODE597                                          -6.869970
# NODE598                                          -6.869970
# NODE599                                          -6.869970
#
#                                      mugration_country_lon  \
# sample
# Reference                                      -100.445882
# GCA_009909635.1_ASM990963v1_genomic              97.745306
# GCA_009669545.1_ASM966954v1_genomic             104.999927
# GCA_009669555.1_ASM966955v1_genomic             104.999927
# GCA_009669565.1_ASM966956v1_genomic             104.999927
# ...                                                    ...
# NODE595                                         -75.045851
# NODE596                                         -75.045851
# NODE597                                         -75.045851
# NODE598                                         -75.045851
# NODE599                                         -75.045851
#
#                                      mugration_province_lat  \
# sample
# Reference                                         38.725178
# GCA_009909635.1_ASM990963v1_genomic               47.622245
# GCA_009669545.1_ASM966954v1_genomic               42.480495
# GCA_009669555.1_ASM966955v1_genomic               42.480495
# GCA_009669565.1_ASM966956v1_genomic               42.480495
# ...                                                     ...
# NODE595                                           -6.250000
# NODE596                                           -6.250000
# NODE597                                           -6.250000
# NODE598                                           -6.250000
# NODE599                                           -6.250000
#
#                                      mugration_province_lon  \
# sample
# Reference                                       -105.607716
# GCA_009909635.1_ASM990963v1_genomic               40.795794
# GCA_009669545.1_ASM966954v1_genomic               85.463346
# GCA_009669555.1_ASM966955v1_genomic               85.463346
# GCA_009669565.1_ASM966956v1_genomic               85.463346
# ...                                                     ...
# NODE595                                          -78.833333
# NODE596                                          -78.833333
# NODE597                                          -78.833333
# NODE598                                          -78.833333
# NODE599                                          -78.833333
#
#                                      branch_length_sub  branch_length_time  \
# sample
# Reference                                    16.935846           162.52800
# GCA_009909635.1_ASM990963v1_genomic           8.966111           878.89200
# GCA_009669545.1_ASM966954v1_genomic           0.000000             9.23246
# GCA_009669555.1_ASM966955v1_genomic           0.996375            24.38400
# GCA_009669565.1_ASM966956v1_genomic           1.992328            35.90130
# ...                                                ...                 ...
# NODE595                                       0.933362             0.00000
# NODE596                                       0.996375             0.00000
# NODE597                                       1.235320            33.20350
# NODE598                                       0.211878            41.19420
# NODE599                                       0.950701            15.99410
#
#                                          rate_sub  rate_sub_year date_lower  \
# sample
# Reference                            2.463945e-08       0.104203       1992
# GCA_009909635.1_ASM990963v1_genomic  2.412242e-09       0.010202       1923
# GCA_009669545.1_ASM966954v1_genomic  0.000000e+00       0.000000       2006
# GCA_009669555.1_ASM966955v1_genomic  9.662073e-09       0.040862       2005
# GCA_009669565.1_ASM966956v1_genomic  1.312209e-08       0.055495       2005
# ...                                           ...            ...        ...
# NODE595                              0.000000e+00       0.000000         NA
# NODE596                              0.000000e+00       0.000000         NA
# NODE597                              8.797265e-09       0.037204         NA
# NODE598                              1.216191e-09       0.005143         NA
# NODE599                              1.405518e-08       0.059441         NA
#
#                                     date_upper  divtree_coord_x  \
# sample
# Reference                                 1992         0.000073
# GCA_009909635.1_ASM990963v1_genomic       1923         0.000073
# GCA_009669545.1_ASM966954v1_genomic       2006         0.000054
# GCA_009669555.1_ASM966955v1_genomic       2005         0.000055
# GCA_009669565.1_ASM966956v1_genomic       2005         0.000055
# ...                                        ...              ...
# NODE595                                     NA         0.000072
# NODE596                                     NA         0.000072
# NODE597                                     NA         0.000073
# NODE598                                     NA         0.000072
# NODE599                                     NA         0.000072
#
#                                      divtree_coord_y  rtt_dist  \
# sample
# Reference                                     509.00  0.000073
# GCA_009909635.1_ASM990963v1_genomic           339.00  0.000073
# GCA_009669545.1_ASM966954v1_genomic           152.00  0.000054
# GCA_009669555.1_ASM966955v1_genomic           171.00  0.000055
# GCA_009669565.1_ASM966956v1_genomic           173.00  0.000055
# ...                                              ...       ...
# NODE595                                       598.25  0.000072
# NODE596                                       596.75  0.000072
# NODE597                                       597.50  0.000073
# NODE598                                       599.75  0.000072
# NODE599                                       600.50  0.000072
#
#                                      timetree_coord_x  timetree_coord_y  \
# sample
# Reference                                 5249.006080            509.00
# GCA_009909635.1_ASM990963v1_genomic       5180.006106            339.00
# GCA_009669545.1_ASM966954v1_genomic       5263.005722            152.00
# GCA_009669555.1_ASM966955v1_genomic       5262.005752            171.00
# GCA_009669565.1_ASM966956v1_genomic       5262.005752            173.00
# ...                                               ...               ...
# NODE595                                   5166.429640            598.25
# NODE596                                   5166.429640            596.75
# NODE597                                   5199.633140            597.50
# NODE598                                   5207.623840            599.75
# NODE599                                   5223.617940            600.50
#
#                                      timetree_date_calendar  \
# sample
# Reference                                            1992.0
# GCA_009909635.1_ASM990963v1_genomic                  1923.0
# GCA_009669545.1_ASM966954v1_genomic                  2006.0
# GCA_009669555.1_ASM966955v1_genomic                  2005.0
# GCA_009669565.1_ASM966956v1_genomic                  2005.0
# ...                                                     ...
# NODE595                                              1910.0
# NODE596                                              1910.0
# NODE597                                              1943.0
# NODE598                                              1951.0
# NODE599                                              1967.0
#
#                                      timetree_CI_lower_err  \
# sample
# Reference                                              0.0
# GCA_009909635.1_ASM990963v1_genomic                    0.0
# GCA_009669545.1_ASM966954v1_genomic                    0.0
# GCA_009669555.1_ASM966955v1_genomic                    0.0
# GCA_009669565.1_ASM966956v1_genomic                    0.0
# ...                                                    ...
# NODE595                                               26.0
# NODE596                                               26.0
# NODE597                                               38.0
# NODE598                                               36.0
# NODE599                                               34.0
#
#                                      timetree_CI_upper_err  \
# sample
# Reference                                              0.0
# GCA_009909635.1_ASM990963v1_genomic                    0.0
# GCA_009669545.1_ASM966954v1_genomic                    0.0
# GCA_009669555.1_ASM966955v1_genomic                    0.0
# GCA_009669565.1_ASM966956v1_genomic                    0.0
# ...                                                    ...
# NODE595                                               22.0
# NODE596                                               22.0
# NODE597                                               28.0
# NODE598                                               30.0
# NODE599                                               27.0
#
#                                                       country_date_strain  \
# sample
# Reference                            United States of America (1992) CO92
# GCA_009909635.1_ASM990963v1_genomic                  Russia (1923.0) 9_10
# GCA_009669545.1_ASM966954v1_genomic                  China (2006.0) 42126
# GCA_009669555.1_ASM966955v1_genomic                  China (2005.0) 42123
# GCA_009669565.1_ASM966956v1_genomic                  China (2005.0) 42118
# ...                                                                   ...
# NODE595                                                                NA
# NODE596                                                                NA
# NODE597                                                                NA
# NODE598                                                                NA
# NODE599                                                                NA
#
#                                                      province_date_strain  \
# sample
# Reference                            United States of America (1992) CO92
# GCA_009909635.1_ASM990963v1_genomic                  Russia (1923.0) 9_10
# GCA_009669545.1_ASM966954v1_genomic                  China (2006.0) 42126
# GCA_009669555.1_ASM966955v1_genomic                  China (2005.0) 42123
# GCA_009669565.1_ASM966956v1_genomic                  China (2005.0) 42118
# ...                                                                   ...
# NODE595                                                                NA
# NODE596                                                                NA
# NODE597                                                                NA
# NODE598                                                                NA
# NODE599                                                                NA
#
#                                      root_geo_dist  population_geo_dist
# sample
# Reference                             11486.934170         11299.492458
# GCA_009909635.1_ASM990963v1_genomic    3257.927659          3336.855636
# GCA_009669545.1_ASM966954v1_genomic     823.027149             0.000000
# GCA_009669555.1_ASM966955v1_genomic     823.027149             0.000000
# GCA_009669565.1_ASM966956v1_genomic     823.027149             0.000000
# ...                                            ...                  ...
# NODE595                               16711.452350         16887.182260
# NODE596                               16711.452350         16887.182260
# NODE597                               16711.452350         16887.182260
# NODE598                               16711.452350         16887.182260
# NODE599                               16711.452350         16887.182260
#
# [1201 rows x 90 columns]

# %% [markdown]
# ## MRCA and Divergence Locations

# %%
mrca_stats_path = os.path.join(mugration_dir, "mrca_stats.txt")

mrca_stats_df = pd.read_csv(mrca_stats_path, sep='\t')
mrca_stats_df.set_index(mrca_stats_df.columns[0], inplace=True)
mrca_stats_df.fillna(NO_DATA_CHAR, inplace=True)


divergence_stats_path = os.path.join(mugration_dir, "divergence_stats.txt")

divergence_stats_df = pd.read_csv(divergence_stats_path, sep='\t')
divergence_stats_df.set_index(divergence_stats_df.columns[0], inplace=True)
divergence_stats_df.fillna(0, inplace=True)


geo_structure_path = os.path.join(mugration_dir, "geographic_structure_stats.txt")

geo_structure_df = pd.read_csv(geo_structure_path, sep='\t')
geo_structure_df.set_index(geo_structure_df.columns[0], inplace=True)
geo_structure_df.fillna(NO_DATA_CHAR, inplace=True)

# %% [markdown]
# ## Structure Plot

# %%
DPI=200
FIGSIZE=[12,4]
geo_res = ["continent", "country", "province"]
## All
fig, axes = plt.subplots(1, 3, figsize=FIGSIZE, dpi=DPI, sharey=True, gridspec_kw={"width_ratios": [1,1,1]})
fig.subplots_adjust(wspace=0.1)
ax_i = 0
df = geo_structure_df

# -------------------------------
# Continent
for geo in geo_res:
    ax = axes[ax_i]
    ax_i += 1
    
    # Bar Plot
    sns.barplot(
        ax=ax,
        data=df,
        y=df.index,
        x=geo + "_structure",
        ec="black",
        order=df.index,
        palette=colors_dict["population"]
    )
    
    # Text Annotations
    y = 0
    for population in df.index:
        loc = df[geo + "_locations"][population]
        conf = round(df[geo + "_structure"][population])
        x = conf - 1
        
        if conf == 0:
            loc = ""
            conf = "No Data"
        else:
            conf = str(conf) + "%"
            
        
        # Location
        ax.text(x, y + 0.05, str(loc), ha="right", va="center", fontsize=8)
        # Confidence
        ax.text(x + 1, y + 0.05, "- " + str(conf), ha="left", va="center", fontsize=6)
        y += 1
        
    ax.set_title(geo.title(), fontweight="bold")
    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_xlim(-5,120)
    ax.set_ylim(len(df),-1)
    
axes[1].set_xlabel("\nPercent of Samples Collected from the Same Location as their Closest Genetic Relative (%)", fontweight="bold")
axes[0].set_ylabel("Population", fontweight="bold")
#fig.suptitle("Geographic Structure", y=1.05, fontsize=14,fontweight="bold")

# Save
out_path = os.path.join(mugration_dir, "geographic_structure_stats")
plt.savefig(out_path + ".png", bbox_inches="tight")
plt.savefig(out_path + ".svg", bbox_inches="tight")

# %% [markdown]
# ### MRCA Plot

# %%
DPI=200
FIGSIZE=[12,4]
geo_res = ["continent", "country", "province"]
## All
fig, axes = plt.subplots(1, 3, figsize=FIGSIZE, dpi=DPI, sharey=True, gridspec_kw={"width_ratios": [1,1,1]})
fig.subplots_adjust(wspace=0.1)
ax_i = 0
df = mrca_stats_df

# -------------------------------
# Continent
for geo in geo_res:
    ax = axes[ax_i]
    ax_i += 1
    
    # Bar Plot
    sns.barplot(
        ax=ax,
        data=df,
        y=df.index,
        x=geo + "_confidence",
        ec="black",
        order=df.index,
        palette=colors_dict["population"]
    )
    
    # Text Annotations
    y = 0
    for population in df.index:
        loc = df[geo][population]
        conf = round(df[geo + "_confidence"][population])
        x = conf - 1
        
        if conf == 0:
            loc = ""
            conf = "No Data"
        else:
            conf = str(conf) + "%"
            
        
        # Location
        ax.text(x, y + 0.05, str(loc), ha="right", va="center", fontsize=8)
        # Confidence
        ax.text(x + 1, y + 0.05, "- " + str(conf), ha="left", va="center", fontsize=6)
        y += 1
        
    ax.set_title(geo.title(), fontweight="bold")
    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_xlim(-5,120)
    ax.set_ylim(len(df),-1)
    
axes[0].set_ylabel("Population", fontweight="bold")
axes[1].set_xlabel("\nConfidence (%)", fontweight="bold")
#fig.suptitle("Location of the Most Recent Common Ancestor (MRCA)", y=1.05, fontsize=12,fontweight="bold")

# Save
out_path = os.path.join(mugration_dir, "mrca_stats")
plt.savefig(out_path + ".png", bbox_inches="tight")
plt.savefig(out_path + ".svg", bbox_inches="tight")

# %% [markdown]
# ### Divergence Plot

# %%
DPI=200
FIGSIZE=[12,4]
geo_res = ["continent", "country", "province"]
## All
fig, axes = plt.subplots(1, 3, figsize=FIGSIZE, dpi=DPI, sharey=True, gridspec_kw={"width_ratios": [1,1,1]})
fig.subplots_adjust(wspace=0.1)
ax_i = 0
df = divergence_stats_df
# -------------------------------
# Continent
for geo in geo_res:
    ax = axes[ax_i]
    ax_i += 1
    
    # Bar Plot
    sns.barplot(
        ax=ax,
        data=df,
        y=df.index,
        x=geo + "_confidence",
        ec="black",
        order=df.index,
        palette=colors_dict["population"]
    )
    
    # Text Annotations
    y = 0
    for population in df.index:
        loc = df[geo][population]
        conf = round(df[geo + "_confidence"][population])
        x = conf - 1
        
        if conf == 0:
            loc = ""
            conf = "No Data"
        else:
            conf = str(conf) + "%"
            
        
        # Location
        ax.text(x, y + 0.05, str(loc), ha="right", va="center", fontsize=8)
        # Confidence
        ax.text(x + 1, y + 0.05, "- " + str(conf), ha="left", va="center", fontsize=6)
        y += 1
        
    ax.set_title(geo.title(), fontweight="bold")
    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_xlim(-5,120)
    ax.set_ylim(len(df),-1)
    
axes[0].set_ylabel("Population", fontweight="bold")
axes[1].set_xlabel("\nConfidence (%)", fontweight="bold")
#fig.suptitle("", y=1.05, fontsize=14,fontweight="bold")

# Save
out_path = os.path.join(mugration_dir, "divergence_stats")
plt.savefig(out_path + ".png", bbox_inches="tight")
plt.savefig(out_path + ".svg", bbox_inches="tight")

# %% [markdown]
# ---
# # 4. EXPORT

# %% [markdown]
# ## Time Tree

# %%
out_timetree = copy.deepcopy(timetree)

for c in out_timetree.find_clades():
    if not c.confidence:
        c.confidence = 0

metadata_to_comment(out_timetree, metadata_df)    
out_timetree_nex_path = os.path.join(augur_dir, "all.timetree.nex")
Phylo.write(out_timetree, out_timetree_nex_path, "nexus")

for c in out_timetree.find_clades():
    c.comment = None

out_timetree_nwk_path = os.path.join(augur_dir, "all.timetree.nwk")
Phylo.write(out_timetree, out_timetree_nwk_path, "newick")

# %% [markdown]
# # Divergence Tree

# %%
out_divtree = copy.deepcopy(divtree)

for c in out_divtree.find_clades():
    if not c.confidence:
        c.confidence = 0

metadata_to_comment(out_divtree, metadata_df)    
out_divtree_nex_path = os.path.join(augur_dir, "all.divtree.nex")
Phylo.write(out_divtree, out_divtree_nex_path, "nexus", format_branch_length="%1.10f")

for c in out_divtree.find_clades():
    c.comment = None

out_divtree_nwk_path = os.path.join(augur_dir, "all.divtree.nwk")
Phylo.write(out_divtree, out_divtree_nwk_path, "newick", format_branch_length="%1.10f")

# %% [markdown]
# ## Metadata

# %%
out_path_metadata = out_divtree_nwk_path = os.path.join(augur_dir, "metadata.tsv")
metadata_df.to_csv(out_path_metadata, sep="\t", index=True)

# %% [markdown]
# ## Augur

# %% [markdown]
# ### Reduced Dataframe

# %%
# Remember, order mug attrs when dealing with confidence!

columns = [
    # Draw Divergence Tree
    "branch_length",
    "branch_length_sub",
    # Draw Time Tree
    "branch_length_time",
    "timetree_date_calendar",
    "date_mean",
    "date_err",
    "date_bp_mean",    
    # Branch Support
    "branch_support",
    "branch_support_conf_category",  
    "branch_support_conf_char",  
    # Filters
    "branch_minor",
    "node_type",
    "branch_number",
    "host_human",
    
    # Text Description
    "biosample_accession",
    "strain",
    "country_date_strain",
    "province_date_strain",
    
    # Stats
    "root_rtt_dist",
    "population_rtt_dist",
    "root_geo_dist",
    "population_geo_dist",
    "rate_sub",
    "rate_sub_year", 
    "tstv",
    "ns_ss_ratio",
    "other_var_ratio",
]

for attr in mug_dict:
    mug_colname = "mugration_" + attr
    conf_colname = "mugration_" + attr + "_confidence"
    
    lat_colname = attr + "_lat"
    lon_colname = attr + "_lon"
    if lat_colname in metadata_df.columns:
        lat_colname = "mugration_" + lat_colname
        lon_colname = "mugration_" + lon_colname
        columns.append(lat_colname)
        columns.append(lon_colname)
    
    columns.append(attr)
    columns.append(mug_colname)
    columns.append(conf_colname)
    

# Edit df
auspice_df = copy.copy(metadata_df[columns])
auspice_df["timetree_num_date_confidence"] = [NO_DATA_CHAR] * len(auspice_df)
auspice_df["node_name"] = list(auspice_df.index)
auspice_df["blank"] = [" "] * len(auspice_df)

# Retype mugration confidence and add categories
for attr in mug_dict:
    colname = attr + "_conf_category"
    for rec in auspice_df.iterrows():
        sample = rec[0]
        conf = auspice_df["mugration_" + attr + "_confidence"][sample]
        
        category = "LOW"
        if conf >= 0.95:
            category = "HIGH"
        auspice_df.at[sample, colname] = category
        
        # Recode to str
        #str_conf = str(int(conf * 100))
        #auspice_df.at[sample, "mugration_" + attr + "_confidence"] = str_conf
        
# Date formating
for rec in metadata_df.iterrows():
    sample = rec[0]
    date = rec[1]["timetree_date_calendar"]
    date_lower = float(date) - rec[1]["timetree_CI_lower_err"]
    date_upper = float(date) + rec[1]["timetree_CI_upper_err"]
    date_confidence = [date_lower, date_upper]
    auspice_df.at[sample,"timetree_num_date_confidence"] = date_confidence
    
    # Rounding
    auspice_df.at[sample, "branch_length_sub"] = round(auspice_df["branch_length_sub"][sample])
    auspice_df.at[sample, "branch_length_time"] = round(auspice_df["branch_length_time"][sample])

        
# Rename columns
for attr in mug_dict:
    auspice_df.rename(columns={attr: attr + "_raw"}, inplace=True)    

auspice_df.rename(columns={"timetree_date_calendar": "timetree_num_date"}, inplace=True)
auspice_df.rename(columns={"mugration_country_lat": "country_lat"}, inplace=True)
auspice_df.rename(columns={"mugration_country_lon": "country_lon"}, inplace=True)
auspice_df.rename(columns={"mugration_province_lat": "province_lat"}, inplace=True)
auspice_df.rename(columns={"mugration_province_lon": "province_lon"}, inplace=True)

# Replace no data
#auspice_df.replace(to_replace=NO_DATA_CHAR, value="Not Available", inplace=True)
display(auspice_df)

# %% [markdown]
# ### JSON

# %%
augur_dict = augur_export(
    tree_path=None, 
    aln_path=None,  
    tree=divtree, 
    tree_df=auspice_df, 
    color_keyword_exclude=["geometry"],
    type_convert = {
        "branch_number" : (lambda x : str(x))
    },
)

print(augur_dict["nodes"]["Reference"])
#print(augur_dict["nodes"]["GCA_002981995.1_ASM298199v1_genomic"])

out_path_augur_json = os.path.join(augur_dir, "all.json" )
utils.write_json(data=augur_dict, file_name=out_path_augur_json, indent=JSON_INDENT)

# %% [markdown]
# ## Auspice

# %% [markdown]
# ### JSON

# %%
#import sys, importlib
#importlib.reload(sys.modules['functions'])
#from functions import auspice_export, branch_attributes

auspice_dict = auspice_export(
    tree=divtree,
    augur_json_paths=[out_path_augur_json], 
    auspice_config_path=auspice_config_path, 
    auspice_colors_path=out_path_colors,
    auspice_latlons_path=out_path_latlon, 
    )


label_col = list(auspice_df.columns)

# Recursively add branch attrs
branch_attributes(
    tree_dict=auspice_dict["tree"], 
    sub_dict=auspice_dict["tree"], 
    df=auspice_df,
    label_col=label_col,
    )

# Last manual changes
auspice_dict_copy = copy.deepcopy(auspice_dict)
for i in range(0, len(auspice_dict_copy["meta"]["colorings"])):
    coloring = auspice_dict_copy["meta"]["colorings"][i]
    for key in coloring:
        # Node type as internal or terminal
        if coloring[key] == "node_type":
            auspice_dict["meta"]["colorings"][i]['scale'] = [['internal', '#FFFFFF'], ['terminal', '#000000']]
            #print(auspice_dict["meta"]["colorings"][i])
        # Confidence category
        if "conf_category" in coloring[key]:
            auspice_dict["meta"]["colorings"][i]['scale'] = [['LOW', '#FFFFFF'], ['HIGH', '#000000']]
            #print(auspice_dict["meta"]["colorings"][i])
        # Host Human binary
        #if "host_human" in coloring[key]:
        #    auspice_dict["meta"]["colorings"][i]['scale'] = [['Human', '#CBB742'], ['Non-Human', "#60B6F2"], ['NA', "#D6D6D6"]]

        
# Write outputs - For Local Rendering
out_path_auspice_local_json = os.path.join(auspice_dir, "all.json" )
utils.write_json(data=auspice_dict, file_name=out_path_auspice_local_json, indent=JSON_INDENT, include_version=False)
export_v2.validate_data_json(out_path_auspice_local_json)
print("Validation successful for local JSON.\n")

#out_path_auspice_remote_json = os.path.join(auspice_dir, "{}_all.json".format(AUSPICE_PREFIX))
#utils.write_json(data=auspice_dict, file_name=out_path_auspice_local_json, indent=JSON_INDENT, include_version=False)
#export_v2.validate_data_json(out_path_auspice_local_json)
#print("Validation successful for local JSON.\n")

# %% [markdown]
# ## Subtrees

# %%
#import sys, importlib
#importlib.reload(sys.modules['functions'])
#from functions import extract_subtree

for population in population_list:
    timetree_copy = copy.deepcopy(timetree)
    
    # Create the subtree df
    df = metadata_df[metadata_df["population"] == population]
    color = df["population_color"][0]
    
    #if len(subtree_df) < 2: continue
    print(population, color)

    df.sort_values("timetree_coord_y", inplace=True)
    tips = df[df["node_type"] == "terminal"]
    internals = df[df["node_type"] == "internal"]
    
    # ----------------------------------------------
    # Subtree Timetree
    subtree = extract_subtree(
        tree=timetree_copy, 
        tips=list(tips.index), 
        df=metadata_df, 
        color_branches=False)
    
    metadata_to_comment(subtree, metadata_df)   


    out_subtree_nex_path = os.path.join(augur_dir, "{}.timetree.nex".format(population))
    Phylo.write(subtree, out_subtree_nex_path, "nexus")
    out_subtree_nwk_path = os.path.join(augur_dir, "{}.timetree.nwk".format(population))
    Phylo.write(subtree, out_subtree_nwk_path, "newick")
    
    # ----------------------------------------------
    # Subtree divtree
    divtree_copy = copy.deepcopy(divtree)
    subtree_div = extract_subtree(
        tree=divtree_copy, 
        tips=list(tips.index), 
        df=metadata_df, 
        color_branches=False)
    
    metadata_to_comment(subtree_div, metadata_df)   
    out_subtree_path = os.path.join(augur_dir, "{}.divtree.nex".format(population))
    Phylo.write(subtree, out_subtree_path, "nexus", format_branch_length="%1.10f")

    #fig, ax = plt.subplots(1)
    #Phylo.draw(subtree, axes=ax, show_confidence=False, label_func = lambda x: '', do_show=False)
    
    augur_dict = augur_export(
        tree_path=None, 
        aln_path=None,  
        tree=subtree, 
        tree_df=auspice_df, 
        color_keyword_exclude=["geometry"],
        type_convert = {
            "branch_number" : (lambda x : str(x))
        },
    ) 
        
    out_path_augur_json = os.path.join(augur_dir, "{}.json".format(population) )
    utils.write_json(data=augur_dict, file_name=out_path_augur_json, indent=JSON_INDENT)

    auspice_dict = auspice_export(
        tree=subtree,
        augur_json_paths=[out_path_augur_json], 
        auspice_config_path=auspice_config_path, 
        auspice_colors_path=out_path_colors,
        auspice_latlons_path=out_path_latlon, 
        )    
    
    label_col = list(auspice_df.columns)

    # Recursively add branch attrs
    branch_attributes(
        tree_dict=auspice_dict["tree"], 
        sub_dict=auspice_dict["tree"], 
        df=auspice_df,
        label_col=label_col,
        )    
    
    # Last manual changes
    auspice_dict_copy = copy.deepcopy(auspice_dict)
    for i in range(0, len(auspice_dict_copy["meta"]["colorings"])):
        coloring = auspice_dict_copy["meta"]["colorings"][i]
        for key in coloring:
            # Node type as internal or terminal
            if coloring[key] == "node_type":
                auspice_dict["meta"]["colorings"][i]['scale'] = [['internal', '#FFFFFF'], ['terminal', color]]
                #print(auspice_dict["meta"]["colorings"][i])
            # Confidence category
            if "conf_category" in coloring[key]:
                auspice_dict["meta"]["colorings"][i]['scale'] = [['LOW', '#FFFFFF'], ['HIGH', color]]
                #print(auspice_dict["meta"]["colorings"][i]) 
    
    # Write outputs - For Local Rendering
    out_path_auspice_local_json = os.path.join(auspice_dir, "{}.json".format(population) )
    utils.write_json(data=auspice_dict, file_name=out_path_auspice_local_json, indent=JSON_INDENT, include_version=False)
    export_v2.validate_data_json(out_path_auspice_local_json)
    print("Validation successful for local JSON.\n")
